# %% [markdown]
# # Funnel.add() 方法签名
#
#
# add(name, attr, value,
#     funnel_sort="ascending", funnel_gap=0, **kwargs)

# %% [markdown]
# name -> str
# 图例名称
# attr -> list
# 属性名称
# value -> list
# 属性所对应的值
# funnel_sort -> str/func
# 数据排序， 可以取 'ascending'，'descending'，'none'（表示按 data 顺序，即不排序）。
# funnel_gap- > int
# 数据图形间距。默认为 0。

# %%
from pyecharts import Funnel

# %%
#标签显示在内部

attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
value = [20, 40, 60, 80, 100, 120]
funnel = Funnel("漏斗图示例")
funnel.add(
    "商品",
    attr,
    value,
    is_label_show=True,
    label_pos="inside",
    label_text_color="#fff",
)
# funnel.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="89e20051aedb4640b6cda40afdd0270a" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_89e20051aedb4640b6cda40afdd0270a = echarts.init(document.getElementById('89e20051aedb4640b6cda40afdd0270a'), 'light', {renderer: 'canvas'});
#
# var option_89e20051aedb4640b6cda40afdd0270a = {
#     "legend": [
#         {
#             "left": "center",
#             "top": "top",
#             "show": true,
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "selectedMode": "multiple",
#             "data": [
#                 "\u96ea\u7eba\u886b",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u88e4\u5b50",
#                 "\u886c\u886b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "text": "\u6f0f\u6597\u56fe\u793a\u4f8b",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "top": "auto"
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         },
#         "top": "center"
#     },
#     "animation": true,
#     "tooltip": {
#         "axisPointer": {
#             "type": "line"
#         },
#         "trigger": "item",
#         "borderColor": "#333",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "triggerOn": "mousemove|click",
#         "textStyle": {
#             "fontSize": 14
#         }
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "gap": 0,
#             "name": "\u5546\u54c1",
#             "sort": "descending",
#             "type": "funnel",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "inside",
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#fff"
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "data": [
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u7f8a\u6bdb\u886b",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u96ea\u7eba\u886b",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 80
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 120
#                 }
#             ]
#         }
#     ],
#     "series_id": 6156491
# };
# myChart_89e20051aedb4640b6cda40afdd0270a.setOption(option_89e20051aedb4640b6cda40afdd0270a);
#
#     });
# </script>

# %%
# 标签显示在外部

funnel = Funnel("漏斗图示例", width=600, height=400, title_pos='center')
funnel.add(
    "商品",
    attr,
    value,
    is_label_show=True,
    label_pos="outside",
    legend_orient="vertical",
    legend_pos="left",
)
# funnel.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="1807b0eed58446abb0f14666ab6c13ef" style="width:600px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_1807b0eed58446abb0f14666ab6c13ef = echarts.init(document.getElementById('1807b0eed58446abb0f14666ab6c13ef'), 'light', {renderer: 'canvas'});
#
# var option_1807b0eed58446abb0f14666ab6c13ef = {
#     "legend": [
#         {
#             "left": "left",
#             "top": "top",
#             "show": true,
#             "orient": "vertical",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "selectedMode": "multiple",
#             "data": [
#                 "\u96ea\u7eba\u886b",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u88e4\u5b50",
#                 "\u886c\u886b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "center",
#             "text": "\u6f0f\u6597\u56fe\u793a\u4f8b",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "top": "auto"
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         },
#         "top": "center"
#     },
#     "animation": true,
#     "tooltip": {
#         "axisPointer": {
#             "type": "line"
#         },
#         "trigger": "item",
#         "borderColor": "#333",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "triggerOn": "mousemove|click",
#         "textStyle": {
#             "fontSize": 14
#         }
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "gap": 0,
#             "name": "\u5546\u54c1",
#             "sort": "descending",
#             "type": "funnel",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "data": [
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u7f8a\u6bdb\u886b",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u96ea\u7eba\u886b",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 80
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 120
#                 }
#             ]
#         }
#     ],
#     "series_id": 2825266
# };
# myChart_1807b0eed58446abb0f14666ab6c13ef.setOption(option_1807b0eed58446abb0f14666ab6c13ef);
#
#     });
# </script>

# %%
#数据按升序排序

funnel = Funnel("漏斗图示例", width=600, height=400, title_pos='center')
funnel.add(
    "商品",
    attr,
    value,
    is_label_show=True,
    label_pos="inside",
    label_text_color="#fff",
    funnel_sort="ascending"
)
# funnel.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="ce006af4d7e44fc4ae9cfd22b036cef7" style="width:600px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_ce006af4d7e44fc4ae9cfd22b036cef7 = echarts.init(document.getElementById('ce006af4d7e44fc4ae9cfd22b036cef7'), 'light', {renderer: 'canvas'});
#
# var option_ce006af4d7e44fc4ae9cfd22b036cef7 = {
#     "legend": [
#         {
#             "left": "center",
#             "top": "top",
#             "show": true,
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "selectedMode": "multiple",
#             "data": [
#                 "\u96ea\u7eba\u886b",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u88e4\u5b50",
#                 "\u886c\u886b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "center",
#             "text": "\u6f0f\u6597\u56fe\u793a\u4f8b",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "top": "auto"
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         },
#         "top": "center"
#     },
#     "animation": true,
#     "tooltip": {
#         "axisPointer": {
#             "type": "line"
#         },
#         "trigger": "item",
#         "borderColor": "#333",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "triggerOn": "mousemove|click",
#         "textStyle": {
#             "fontSize": 14
#         }
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "gap": 0,
#             "name": "\u5546\u54c1",
#             "sort": "ascending",
#             "type": "funnel",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "inside",
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#fff"
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "data": [
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u7f8a\u6bdb\u886b",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u96ea\u7eba\u886b",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 80
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 120
#                 }
#             ]
#         }
#     ],
#     "series_id": 425386
# };
# myChart_ce006af4d7e44fc4ae9cfd22b036cef7.setOption(option_ce006af4d7e44fc4ae9cfd22b036cef7);
#
#     });
# </script>

# %%
#不排序数据

funnel = Funnel("漏斗图示例", width=600, height=400, title_pos='center')
funnel.add(
    "商品",
    attr,
    value,
    is_label_show=True,
    label_pos="inside",
    label_text_color="#fff",
    funnel_sort="none"
)
# funnel.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="44d4c10144644953be4b0f3388900cf6" style="width:600px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_44d4c10144644953be4b0f3388900cf6 = echarts.init(document.getElementById('44d4c10144644953be4b0f3388900cf6'), 'light', {renderer: 'canvas'});
#
# var option_44d4c10144644953be4b0f3388900cf6 = {
#     "legend": [
#         {
#             "left": "center",
#             "top": "top",
#             "show": true,
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "selectedMode": "multiple",
#             "data": [
#                 "\u96ea\u7eba\u886b",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u88e4\u5b50",
#                 "\u886c\u886b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "center",
#             "text": "\u6f0f\u6597\u56fe\u793a\u4f8b",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "top": "auto"
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         },
#         "top": "center"
#     },
#     "animation": true,
#     "tooltip": {
#         "axisPointer": {
#             "type": "line"
#         },
#         "trigger": "item",
#         "borderColor": "#333",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "triggerOn": "mousemove|click",
#         "textStyle": {
#             "fontSize": 14
#         }
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "gap": 0,
#             "name": "\u5546\u54c1",
#             "sort": "none",
#             "type": "funnel",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "inside",
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#fff"
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "data": [
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u7f8a\u6bdb\u886b",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u96ea\u7eba\u886b",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 80
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 120
#                 }
#             ]
#         }
#     ],
#     "series_id": 337859
# };
# myChart_44d4c10144644953be4b0f3388900cf6.setOption(option_44d4c10144644953be4b0f3388900cf6);
#
#     });
# </script>

# %%
#指定图形间隔

funnel = Funnel("漏斗图示例", width=600, height=400, title_pos='center')
funnel.add(
    "商品",
    attr,
    value,
    is_label_show=True,
    label_pos="inside",
    label_text_color="#fff",
    funnel_sort="ascending",
    funnel_gap=5,
)
# funnel.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="908a057969584203aa94a392b472111a" style="width:600px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_908a057969584203aa94a392b472111a = echarts.init(document.getElementById('908a057969584203aa94a392b472111a'), 'light', {renderer: 'canvas'});
#
# var option_908a057969584203aa94a392b472111a = {
#     "legend": [
#         {
#             "left": "center",
#             "top": "top",
#             "show": true,
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "selectedMode": "multiple",
#             "data": [
#                 "\u96ea\u7eba\u886b",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u88e4\u5b50",
#                 "\u886c\u886b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "center",
#             "text": "\u6f0f\u6597\u56fe\u793a\u4f8b",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "top": "auto"
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         },
#         "top": "center"
#     },
#     "animation": true,
#     "tooltip": {
#         "axisPointer": {
#             "type": "line"
#         },
#         "trigger": "item",
#         "borderColor": "#333",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "triggerOn": "mousemove|click",
#         "textStyle": {
#             "fontSize": 14
#         }
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "gap": 5,
#             "name": "\u5546\u54c1",
#             "sort": "ascending",
#             "type": "funnel",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "inside",
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#fff"
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "data": [
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u7f8a\u6bdb\u886b",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u96ea\u7eba\u886b",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 80
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 120
#                 }
#             ]
#         }
#     ],
#     "series_id": 1759960
# };
# myChart_908a057969584203aa94a392b472111a.setOption(option_908a057969584203aa94a392b472111a);
#
#     });
# </script>
