# %% [markdown]
# # 方法签名
#
# add(name, x_axis, y_axis,
#     is_stack=False,
#     bar_category_gap='20%', **kwargs)
# <br>
# <br>
# 全局配置项要在最后一个 add() 上设置，否侧设置会被冲刷掉。

# %% [markdown]
# <h3>图例名称：</h3>name -> str<br>
#
# <h3>x 坐标轴数据：</h3>x_axis -> list<br>
#
# <h3>y 坐标轴数据：</h3>y_axis -> list<br>
#
# <h3>数据堆叠：</h3>is_stack -> bool<br>
# 同个类目轴上系列配置相同的 stack 值可以堆叠放置<br>
#
# <h3>类目轴的柱状距离：</h3>bar_category_gap -> int/str<br>
# 当设置为 0 时柱状是紧挨着（直方图类型），默认为 '20%'

# %%
from pyecharts import Bar
import random

# %%
#堆叠图
attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
v1 = [5, 20, 36, 10, 75, 90]
v2 = [10, 25, 8, 60, 20, 80]
bar = Bar("柱状图数据堆叠示例")
bar.add("商家A", attr, v1, is_stack=True)
bar.add("商家B", attr, v2, is_stack=True)
# bar.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="79091e42f6ab4821a3f199687f3bfb35" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_79091e42f6ab4821a3f199687f3bfb35 = echarts.init(document.getElementById('79091e42f6ab4821a3f199687f3bfb35'), 'light', {renderer: 'canvas'});
#
# var option_79091e42f6ab4821a3f199687f3bfb35 = {
#     "xAxis": [
#         {
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "nameLocation": "middle",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "nameGap": 25,
#             "boundaryGap": true
#         }
#     ],
#     "series": [
#         {
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "seriesId": 4986326,
#             "stack": "stack_4986326",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             }
#         },
#         {
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 10,
#                 25,
#                 8,
#                 60,
#                 20,
#                 80
#             ],
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "seriesId": 4986326,
#             "stack": "stack_4986326",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "inverse": false,
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "nameLocation": "middle",
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "boundaryGap": true,
#             "nameGap": 25,
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             }
#         }
#     ],
#     "series_id": 4986326,
#     "tooltip": {
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderColor": "#333"
#     },
#     "animation": true,
#     "title": [
#         {
#             "text": "\u67f1\u72b6\u56fe\u6570\u636e\u5806\u53e0\u793a\u4f8b",
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             }
#         }
#     ],
#     "legend": [
#         {
#             "show": true,
#             "orient": "horizontal",
#             "top": "top",
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "left": "center",
#             "selectedMode": "multiple",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "top": "center",
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     }
# };
# myChart_79091e42f6ab4821a3f199687f3bfb35.setOption(option_79091e42f6ab4821a3f199687f3bfb35);
#
#     });
# </script>

# %%
bar = Bar("标记线和标记点示例")
bar.add("商家A", attr, v1, mark_point=["average"])
bar.add("商家B", attr, v2, mark_line=["min", "max"])
# bar.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="0261d2fdc2c9493eac7aff6db79b0bdf" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_0261d2fdc2c9493eac7aff6db79b0bdf = echarts.init(document.getElementById('0261d2fdc2c9493eac7aff6db79b0bdf'), 'light', {renderer: 'canvas'});
#
# var option_0261d2fdc2c9493eac7aff6db79b0bdf = {
#     "xAxis": [
#         {
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "nameLocation": "middle",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "nameGap": 25,
#             "boundaryGap": true
#         }
#     ],
#     "series": [
#         {
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "seriesId": 5137883,
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "symbol": "pin",
#                         "type": "average",
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         },
#                         "symbolSize": 50,
#                         "name": "mean-Value"
#                     }
#                 ]
#             }
#         },
#         {
#             "markLine": {
#                 "symbolSize": 10,
#                 "data": [
#                     {
#                         "type": "min",
#                         "name": "Minimum"
#                     },
#                     {
#                         "type": "max",
#                         "name": "Maximum"
#                     }
#                 ]
#             },
#             "data": [
#                 10,
#                 25,
#                 8,
#                 60,
#                 20,
#                 80
#             ],
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "seriesId": 5137883,
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "inverse": false,
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "nameLocation": "middle",
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "boundaryGap": true,
#             "nameGap": 25,
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             }
#         }
#     ],
#     "series_id": 5137883,
#     "tooltip": {
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderColor": "#333"
#     },
#     "animation": true,
#     "title": [
#         {
#             "text": "\u6807\u8bb0\u7ebf\u548c\u6807\u8bb0\u70b9\u793a\u4f8b",
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             }
#         }
#     ],
#     "legend": [
#         {
#             "show": true,
#             "orient": "horizontal",
#             "top": "top",
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "left": "center",
#             "selectedMode": "multiple",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "top": "center",
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     }
# };
# myChart_0261d2fdc2c9493eac7aff6db79b0bdf.setOption(option_0261d2fdc2c9493eac7aff6db79b0bdf);
#
#     });
# </script>

# %%
#交换X和Y轴

bar = Bar("x 轴和 y 轴交换")
bar.add("商家A", attr, v1)
bar.add("商家B", attr, v2, is_convert=True)
# bar.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="ea3149232e0a48beaac3f8c6f52e46b7" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_ea3149232e0a48beaac3f8c6f52e46b7 = echarts.init(document.getElementById('ea3149232e0a48beaac3f8c6f52e46b7'), 'light', {renderer: 'canvas'});
#
# var option_ea3149232e0a48beaac3f8c6f52e46b7 = {
#     "xAxis": [
#         {
#             "inverse": false,
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "nameLocation": "middle",
#             "type": "value",
#             "splitLine": {
#                 "show": false
#             },
#             "boundaryGap": true,
#             "nameGap": 25,
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             }
#         }
#     ],
#     "series": [
#         {
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "seriesId": 1834337,
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             }
#         },
#         {
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 10,
#                 25,
#                 8,
#                 60,
#                 20,
#                 80
#             ],
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "seriesId": 1834337,
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "type": "category",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "nameLocation": "middle",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "nameGap": 25,
#             "boundaryGap": true
#         }
#     ],
#     "series_id": 1834337,
#     "tooltip": {
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderColor": "#333"
#     },
#     "animation": true,
#     "title": [
#         {
#             "text": "x \u8f74\u548c y \u8f74\u4ea4\u6362",
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             }
#         }
#     ],
#     "legend": [
#         {
#             "show": true,
#             "orient": "horizontal",
#             "top": "top",
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "left": "center",
#             "selectedMode": "multiple",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "top": "center",
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     }
# };
# myChart_ea3149232e0a48beaac3f8c6f52e46b7.setOption(option_ea3149232e0a48beaac3f8c6f52e46b7);
#
#     });
# </script>

# %%
#dataZoom 效果，'slider' 类型

attr = ["{}天".format(i) for i in range(30)]
v1 = [random.randint(1, 30) for _ in range(30)]
bar = Bar("Bar - datazoom - slider 示例")
bar.add("", attr, v1, is_label_show=True, is_datazoom_show=True)
# bar.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="aecb919014e745aba040650a8188ed6f" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_aecb919014e745aba040650a8188ed6f = echarts.init(document.getElementById('aecb919014e745aba040650a8188ed6f'), 'light', {renderer: 'canvas'});
#
# var option_aecb919014e745aba040650a8188ed6f = {
#     "xAxis": [
#         {
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "nameLocation": "middle",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "data": [
#                 "0\u5929",
#                 "1\u5929",
#                 "2\u5929",
#                 "3\u5929",
#                 "4\u5929",
#                 "5\u5929",
#                 "6\u5929",
#                 "7\u5929",
#                 "8\u5929",
#                 "9\u5929",
#                 "10\u5929",
#                 "11\u5929",
#                 "12\u5929",
#                 "13\u5929",
#                 "14\u5929",
#                 "15\u5929",
#                 "16\u5929",
#                 "17\u5929",
#                 "18\u5929",
#                 "19\u5929",
#                 "20\u5929",
#                 "21\u5929",
#                 "22\u5929",
#                 "23\u5929",
#                 "24\u5929",
#                 "25\u5929",
#                 "26\u5929",
#                 "27\u5929",
#                 "28\u5929",
#                 "29\u5929"
#             ],
#             "nameGap": 25,
#             "boundaryGap": true
#         }
#     ],
#     "series": [
#         {
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 30,
#                 26,
#                 11,
#                 13,
#                 20,
#                 9,
#                 28,
#                 5,
#                 29,
#                 17,
#                 11,
#                 21,
#                 10,
#                 13,
#                 10,
#                 30,
#                 19,
#                 25,
#                 22,
#                 2,
#                 24,
#                 28,
#                 20,
#                 30,
#                 7,
#                 25,
#                 7,
#                 25,
#                 21,
#                 25
#             ],
#             "type": "bar",
#             "seriesId": 1747887,
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "inverse": false,
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "nameLocation": "middle",
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "boundaryGap": true,
#             "nameGap": 25,
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             }
#         }
#     ],
#     "series_id": 1747887,
#     "tooltip": {
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderColor": "#333"
#     },
#     "animation": true,
#     "title": [
#         {
#             "text": "Bar - datazoom - slider \u793a\u4f8b",
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             }
#         }
#     ],
#     "legend": [
#         {
#             "show": true,
#             "orient": "horizontal",
#             "top": "top",
#             "data": [
#                 ""
#             ],
#             "left": "center",
#             "selectedMode": "multiple",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "top": "center",
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "dataZoom": [
#         {
#             "show": true,
#             "orient": "horizontal",
#             "end": 100,
#             "type": "slider",
#             "start": 50
#         }
#     ]
# };
# myChart_aecb919014e745aba040650a8188ed6f.setOption(option_aecb919014e745aba040650a8188ed6f);
#
#     });
# </script>

# %%
#dataZoom 效果，'inside' 类型

attr = ["{}天".format(i) for i in range(30)]
v1 = [random.randint(1, 30) for _ in range(30)]
bar = Bar("Bar - datazoom - inside 示例")
bar.add(
    "",
    attr,
    v1,
    is_datazoom_show=True,
    datazoom_type="inside",
    datazoom_range=[10, 25],
)
# bar.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="8de7e131a1cf490d953a73ac633e7a41" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_8de7e131a1cf490d953a73ac633e7a41 = echarts.init(document.getElementById('8de7e131a1cf490d953a73ac633e7a41'), 'light', {renderer: 'canvas'});
#
# var option_8de7e131a1cf490d953a73ac633e7a41 = {
#     "xAxis": [
#         {
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "nameLocation": "middle",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "data": [
#                 "0\u5929",
#                 "1\u5929",
#                 "2\u5929",
#                 "3\u5929",
#                 "4\u5929",
#                 "5\u5929",
#                 "6\u5929",
#                 "7\u5929",
#                 "8\u5929",
#                 "9\u5929",
#                 "10\u5929",
#                 "11\u5929",
#                 "12\u5929",
#                 "13\u5929",
#                 "14\u5929",
#                 "15\u5929",
#                 "16\u5929",
#                 "17\u5929",
#                 "18\u5929",
#                 "19\u5929",
#                 "20\u5929",
#                 "21\u5929",
#                 "22\u5929",
#                 "23\u5929",
#                 "24\u5929",
#                 "25\u5929",
#                 "26\u5929",
#                 "27\u5929",
#                 "28\u5929",
#                 "29\u5929"
#             ],
#             "nameGap": 25,
#             "boundaryGap": true
#         }
#     ],
#     "series": [
#         {
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 13,
#                 19,
#                 10,
#                 5,
#                 16,
#                 30,
#                 30,
#                 17,
#                 1,
#                 28,
#                 11,
#                 26,
#                 12,
#                 3,
#                 1,
#                 13,
#                 7,
#                 27,
#                 24,
#                 13,
#                 10,
#                 2,
#                 22,
#                 3,
#                 23,
#                 16,
#                 15,
#                 14,
#                 1,
#                 5
#             ],
#             "type": "bar",
#             "seriesId": 1207962,
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "inverse": false,
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "nameLocation": "middle",
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "boundaryGap": true,
#             "nameGap": 25,
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             }
#         }
#     ],
#     "series_id": 1207962,
#     "tooltip": {
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderColor": "#333"
#     },
#     "animation": true,
#     "title": [
#         {
#             "text": "Bar - datazoom - inside \u793a\u4f8b",
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             }
#         }
#     ],
#     "legend": [
#         {
#             "show": true,
#             "orient": "horizontal",
#             "top": "top",
#             "data": [
#                 ""
#             ],
#             "left": "center",
#             "selectedMode": "multiple",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "top": "center",
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "dataZoom": [
#         {
#             "show": true,
#             "orient": "horizontal",
#             "end": 25,
#             "type": "inside",
#             "start": 10
#         }
#     ]
# };
# myChart_8de7e131a1cf490d953a73ac633e7a41.setOption(option_8de7e131a1cf490d953a73ac633e7a41);
#
#     });
# </script>

# %%
#dataZoom 效果，'both' 类型

attr = ["{}天".format(i) for i in range(30)]
v1 = [random.randint(1, 30) for _ in range(30)]
bar = Bar("Bar - datazoom - both 示例")
bar.add(
    "",
    attr,
    v1,
    is_datazoom_show=True,
    datazoom_type="both",
    datazoom_range=[10, 25],
)
# bar.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="12c3cf284d9b4a2f8a92ca2a714b0d50" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_12c3cf284d9b4a2f8a92ca2a714b0d50 = echarts.init(document.getElementById('12c3cf284d9b4a2f8a92ca2a714b0d50'), 'light', {renderer: 'canvas'});
#
# var option_12c3cf284d9b4a2f8a92ca2a714b0d50 = {
#     "xAxis": [
#         {
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "nameLocation": "middle",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "data": [
#                 "0\u5929",
#                 "1\u5929",
#                 "2\u5929",
#                 "3\u5929",
#                 "4\u5929",
#                 "5\u5929",
#                 "6\u5929",
#                 "7\u5929",
#                 "8\u5929",
#                 "9\u5929",
#                 "10\u5929",
#                 "11\u5929",
#                 "12\u5929",
#                 "13\u5929",
#                 "14\u5929",
#                 "15\u5929",
#                 "16\u5929",
#                 "17\u5929",
#                 "18\u5929",
#                 "19\u5929",
#                 "20\u5929",
#                 "21\u5929",
#                 "22\u5929",
#                 "23\u5929",
#                 "24\u5929",
#                 "25\u5929",
#                 "26\u5929",
#                 "27\u5929",
#                 "28\u5929",
#                 "29\u5929"
#             ],
#             "nameGap": 25,
#             "boundaryGap": true
#         }
#     ],
#     "series": [
#         {
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 3,
#                 17,
#                 20,
#                 4,
#                 18,
#                 7,
#                 17,
#                 18,
#                 5,
#                 15,
#                 29,
#                 21,
#                 4,
#                 6,
#                 17,
#                 30,
#                 11,
#                 17,
#                 17,
#                 20,
#                 21,
#                 13,
#                 22,
#                 7,
#                 11,
#                 9,
#                 23,
#                 6,
#                 26,
#                 24
#             ],
#             "type": "bar",
#             "seriesId": 393074,
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "inverse": false,
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "nameLocation": "middle",
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "boundaryGap": true,
#             "nameGap": 25,
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             }
#         }
#     ],
#     "series_id": 393074,
#     "tooltip": {
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderColor": "#333"
#     },
#     "animation": true,
#     "title": [
#         {
#             "text": "Bar - datazoom - both \u793a\u4f8b",
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             }
#         }
#     ],
#     "legend": [
#         {
#             "show": true,
#             "orient": "horizontal",
#             "top": "top",
#             "data": [
#                 ""
#             ],
#             "left": "center",
#             "selectedMode": "multiple",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "top": "center",
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "dataZoom": [
#         {
#             "show": true,
#             "orient": "horizontal",
#             "end": 25,
#             "type": "slider",
#             "start": 10
#         },
#         {
#             "show": true,
#             "orient": "horizontal",
#             "end": 25,
#             "type": "inside",
#             "start": 10
#         }
#     ]
# };
# myChart_12c3cf284d9b4a2f8a92ca2a714b0d50.setOption(option_12c3cf284d9b4a2f8a92ca2a714b0d50);
#
#     });
# </script>

# %%
#多 dataZoom 效果，效果同时支持 X、Y 轴

days = ["{}天".format(i) for i in range(30)]
days_v1 = [random.randint(1, 30) for _ in range(30)]
bar = Bar("Bar - datazoom - xaxis/yaxis 示例")
bar.add(
    "",
    days,
    days_v1,
    # 默认为 X 轴，横向
    is_datazoom_show=True,
    datazoom_type="slider",
    datazoom_range=[10, 25],
    # 新增额外的 dataZoom 控制条，纵向
    is_datazoom_extra_show=True,
    datazoom_extra_type="slider",
    datazoom_extra_range=[10, 25],
    is_toolbox_show=False,
)
# bar.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="390de1859c21426298d38e48171b0ce7" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_390de1859c21426298d38e48171b0ce7 = echarts.init(document.getElementById('390de1859c21426298d38e48171b0ce7'), 'light', {renderer: 'canvas'});
#
# var option_390de1859c21426298d38e48171b0ce7 = {
#     "xAxis": [
#         {
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "nameLocation": "middle",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "data": [
#                 "0\u5929",
#                 "1\u5929",
#                 "2\u5929",
#                 "3\u5929",
#                 "4\u5929",
#                 "5\u5929",
#                 "6\u5929",
#                 "7\u5929",
#                 "8\u5929",
#                 "9\u5929",
#                 "10\u5929",
#                 "11\u5929",
#                 "12\u5929",
#                 "13\u5929",
#                 "14\u5929",
#                 "15\u5929",
#                 "16\u5929",
#                 "17\u5929",
#                 "18\u5929",
#                 "19\u5929",
#                 "20\u5929",
#                 "21\u5929",
#                 "22\u5929",
#                 "23\u5929",
#                 "24\u5929",
#                 "25\u5929",
#                 "26\u5929",
#                 "27\u5929",
#                 "28\u5929",
#                 "29\u5929"
#             ],
#             "nameGap": 25,
#             "boundaryGap": true
#         }
#     ],
#     "series": [
#         {
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 15,
#                 2,
#                 4,
#                 29,
#                 18,
#                 10,
#                 21,
#                 12,
#                 28,
#                 6,
#                 10,
#                 25,
#                 4,
#                 2,
#                 10,
#                 8,
#                 2,
#                 7,
#                 23,
#                 18,
#                 23,
#                 16,
#                 25,
#                 4,
#                 30,
#                 22,
#                 25,
#                 8,
#                 15,
#                 2
#             ],
#             "type": "bar",
#             "seriesId": 6878508,
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "inverse": false,
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "nameLocation": "middle",
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "boundaryGap": true,
#             "nameGap": 25,
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             }
#         }
#     ],
#     "series_id": 6878508,
#     "tooltip": {
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderColor": "#333"
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "title": [
#         {
#             "text": "Bar - datazoom - xaxis/yaxis \u793a\u4f8b",
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             }
#         }
#     ],
#     "legend": [
#         {
#             "show": true,
#             "orient": "horizontal",
#             "top": "top",
#             "data": [
#                 ""
#             ],
#             "left": "center",
#             "selectedMode": "multiple",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "dataZoom": [
#         {
#             "show": true,
#             "orient": "horizontal",
#             "end": 25,
#             "type": "slider",
#             "start": 10
#         },
#         {
#             "show": true,
#             "orient": "vertical",
#             "end": 25,
#             "type": "slider",
#             "start": 10
#         }
#     ]
# };
# myChart_390de1859c21426298d38e48171b0ce7.setOption(option_390de1859c21426298d38e48171b0ce7);
#
#     });
# </script>

# %% [markdown]
# ### 当 x 轴或者 y 轴的标签因为过于密集而导致全部显示出来会重叠的话，可采用使标签旋转的方法
#
# ###  可通过设置 xaxis_min/xaxis_max/yaxis_min/yaxis_max 来调整 x 轴和 y 轴上的最大最小值。针对数值轴有效！
# ###  可以通过 label_color 来设置柱状的颜色，如 ['#eee', '#000']，所有的图表类型的图例颜色都可通过 label_color 来修改。

# %%
attr = ["{}天".format(i) for i in range(20)]
v1 = [random.randint(1, 20) for _ in range(20)]
bar = Bar("坐标轴标签旋转示例")
bar.add("", attr, v1, xaxis_interval=0, xaxis_rotate=30, yaxis_rotate=30)
# bar.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="2411cee098c24934b36f23d8870ea8ee" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_2411cee098c24934b36f23d8870ea8ee = echarts.init(document.getElementById('2411cee098c24934b36f23d8870ea8ee'), 'light', {renderer: 'canvas'});
#
# var option_2411cee098c24934b36f23d8870ea8ee = {
#     "xAxis": [
#         {
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "rotate": 30,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "nameLocation": "middle",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "data": [
#                 "0\u5929",
#                 "1\u5929",
#                 "2\u5929",
#                 "3\u5929",
#                 "4\u5929",
#                 "5\u5929",
#                 "6\u5929",
#                 "7\u5929",
#                 "8\u5929",
#                 "9\u5929",
#                 "10\u5929",
#                 "11\u5929",
#                 "12\u5929",
#                 "13\u5929",
#                 "14\u5929",
#                 "15\u5929",
#                 "16\u5929",
#                 "17\u5929",
#                 "18\u5929",
#                 "19\u5929"
#             ],
#             "nameGap": 25,
#             "boundaryGap": true
#         }
#     ],
#     "series": [
#         {
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 4,
#                 18,
#                 18,
#                 18,
#                 19,
#                 16,
#                 14,
#                 6,
#                 6,
#                 17,
#                 16,
#                 4,
#                 19,
#                 20,
#                 4,
#                 20,
#                 4,
#                 4,
#                 16,
#                 9
#             ],
#             "type": "bar",
#             "seriesId": 2512756,
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "inverse": false,
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "nameLocation": "middle",
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "boundaryGap": true,
#             "nameGap": 25,
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "interval": "auto",
#                 "rotate": 30,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             }
#         }
#     ],
#     "series_id": 2512756,
#     "tooltip": {
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderColor": "#333"
#     },
#     "animation": true,
#     "title": [
#         {
#             "text": "\u5750\u6807\u8f74\u6807\u7b7e\u65cb\u8f6c\u793a\u4f8b",
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             }
#         }
#     ],
#     "legend": [
#         {
#             "show": true,
#             "orient": "horizontal",
#             "top": "top",
#             "data": [
#                 ""
#             ],
#             "left": "center",
#             "selectedMode": "multiple",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "top": "center",
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     }
# };
# myChart_2411cee098c24934b36f23d8870ea8ee.setOption(option_2411cee098c24934b36f23d8870ea8ee);
#
#     });
# </script>

# %%
#瀑布图

attr = ["{}月".format(i) for i in range(1, 8)]
v1 = [0, 100, 200, 300, 400, 220, 250]
v2 = [1000, 800, 600, 500, 450, 400, 300]
bar = Bar("瀑布图示例")
# 利用第一个 add() 图例的颜色为透明，即 'rgba(0,0,0,0)'，并且设置 is_stack 标志为 True
bar.add("", attr, v1, label_color=['rgba(0,0,0,0)'], is_stack=True)
bar.add("月份", attr, v2, is_label_show=True, is_stack=True, label_pos='inside')
# bar.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="23a717b56b9e45f6b814639260cb3a45" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_23a717b56b9e45f6b814639260cb3a45 = echarts.init(document.getElementById('23a717b56b9e45f6b814639260cb3a45'), 'light', {renderer: 'canvas'});
#
# var option_23a717b56b9e45f6b814639260cb3a45 = {
#     "xAxis": [
#         {
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "nameLocation": "middle",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "data": [
#                 "1\u6708",
#                 "2\u6708",
#                 "3\u6708",
#                 "4\u6708",
#                 "5\u6708",
#                 "6\u6708",
#                 "7\u6708"
#             ],
#             "nameGap": 25,
#             "boundaryGap": true
#         }
#     ],
#     "series": [
#         {
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 0,
#                 100,
#                 200,
#                 300,
#                 400,
#                 220,
#                 250
#             ],
#             "type": "bar",
#             "seriesId": 2685221,
#             "stack": "stack_2685221",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             }
#         },
#         {
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 1000,
#                 800,
#                 600,
#                 500,
#                 450,
#                 400,
#                 300
#             ],
#             "type": "bar",
#             "name": "\u6708\u4efd",
#             "seriesId": 2685221,
#             "stack": "stack_2685221",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "inside",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "inverse": false,
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "nameLocation": "middle",
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "boundaryGap": true,
#             "nameGap": 25,
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             }
#         }
#     ],
#     "series_id": 2685221,
#     "tooltip": {
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderColor": "#333"
#     },
#     "animation": true,
#     "title": [
#         {
#             "text": "\u7011\u5e03\u56fe\u793a\u4f8b",
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             }
#         }
#     ],
#     "legend": [
#         {
#             "show": true,
#             "orient": "horizontal",
#             "top": "top",
#             "data": [
#                 "",
#                 "\u6708\u4efd"
#             ],
#             "left": "center",
#             "selectedMode": "multiple",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color": [
#         "rgba(0,0,0,0)",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "top": "center",
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     }
# };
# myChart_23a717b56b9e45f6b814639260cb3a45.setOption(option_23a717b56b9e45f6b814639260cb3a45);
#
#     });
# </script>

# %%
#直方图

attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
v1 = [5, 20, 36, 10, 75, 90]
v2 = [10, 25, 8, 60, 20, 80]
bar = Bar("直方图示例")
bar.add("", attr * 2, v1 + v2, bar_category_gap=0)
# bar.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="f4f97efbffb8479e8a25e1a41228909d" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_f4f97efbffb8479e8a25e1a41228909d = echarts.init(document.getElementById('f4f97efbffb8479e8a25e1a41228909d'), 'light', {renderer: 'canvas'});
#
# var option_f4f97efbffb8479e8a25e1a41228909d = {
#     "xAxis": [
#         {
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "nameLocation": "middle",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50",
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "nameGap": 25,
#             "boundaryGap": true
#         }
#     ],
#     "series": [
#         {
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90,
#                 10,
#                 25,
#                 8,
#                 60,
#                 20,
#                 80
#             ],
#             "type": "bar",
#             "seriesId": 3036652,
#             "barCategoryGap": 0,
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "inverse": false,
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "nameLocation": "middle",
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "boundaryGap": true,
#             "nameGap": 25,
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             }
#         }
#     ],
#     "series_id": 3036652,
#     "tooltip": {
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderColor": "#333"
#     },
#     "animation": true,
#     "title": [
#         {
#             "text": "\u76f4\u65b9\u56fe\u793a\u4f8b",
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             }
#         }
#     ],
#     "legend": [
#         {
#             "show": true,
#             "orient": "horizontal",
#             "top": "top",
#             "data": [
#                 ""
#             ],
#             "left": "center",
#             "selectedMode": "multiple",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "top": "center",
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     }
# };
# myChart_f4f97efbffb8479e8a25e1a41228909d.setOption(option_f4f97efbffb8479e8a25e1a41228909d);
#
#     });
# </script>

# %%
#多比较柱形图

attr = ["{}月".format(i) for i in range(1, 13)]
v1 = [2.0, 4.9, 7.0, 23.2, 25.6, 76.7, 135.6, 162.2, 32.6, 20.0, 6.4, 3.3]
v2 = [2.6, 5.9, 9.0, 26.4, 28.7, 70.7, 175.6, 182.2, 48.7, 18.8, 6.0, 2.3]
bar = Bar("柱状图示例")
bar.add("蒸发量", attr, v1, mark_line=["average"], mark_point=["max", "min"])
bar.add("降水量", attr, v2, mark_line=["average"], mark_point=["max", "min"])
# bar.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="e100a503b2944b72a4cf07dd59e020c3" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_e100a503b2944b72a4cf07dd59e020c3 = echarts.init(document.getElementById('e100a503b2944b72a4cf07dd59e020c3'), 'light', {renderer: 'canvas'});
#
# var option_e100a503b2944b72a4cf07dd59e020c3 = {
#     "xAxis": [
#         {
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "nameLocation": "middle",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "data": [
#                 "1\u6708",
#                 "2\u6708",
#                 "3\u6708",
#                 "4\u6708",
#                 "5\u6708",
#                 "6\u6708",
#                 "7\u6708",
#                 "8\u6708",
#                 "9\u6708",
#                 "10\u6708",
#                 "11\u6708",
#                 "12\u6708"
#             ],
#             "nameGap": 25,
#             "boundaryGap": true
#         }
#     ],
#     "series": [
#         {
#             "markLine": {
#                 "symbolSize": 10,
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ]
#             },
#             "data": [
#                 2.0,
#                 4.9,
#                 7.0,
#                 23.2,
#                 25.6,
#                 76.7,
#                 135.6,
#                 162.2,
#                 32.6,
#                 20.0,
#                 6.4,
#                 3.3
#             ],
#             "type": "bar",
#             "name": "\u84b8\u53d1\u91cf",
#             "seriesId": 3992317,
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "symbol": "pin",
#                         "type": "max",
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         },
#                         "symbolSize": 50,
#                         "name": "Maximum"
#                     },
#                     {
#                         "symbol": "pin",
#                         "type": "min",
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         },
#                         "symbolSize": 50,
#                         "name": "Minimum"
#                     }
#                 ]
#             }
#         },
#         {
#             "markLine": {
#                 "symbolSize": 10,
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ]
#             },
#             "data": [
#                 2.6,
#                 5.9,
#                 9.0,
#                 26.4,
#                 28.7,
#                 70.7,
#                 175.6,
#                 182.2,
#                 48.7,
#                 18.8,
#                 6.0,
#                 2.3
#             ],
#             "type": "bar",
#             "name": "\u964d\u6c34\u91cf",
#             "seriesId": 3992317,
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "symbol": "pin",
#                         "type": "max",
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         },
#                         "symbolSize": 50,
#                         "name": "Maximum"
#                     },
#                     {
#                         "symbol": "pin",
#                         "type": "min",
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         },
#                         "symbolSize": 50,
#                         "name": "Minimum"
#                     }
#                 ]
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "inverse": false,
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "nameLocation": "middle",
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "boundaryGap": true,
#             "nameGap": 25,
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             }
#         }
#     ],
#     "series_id": 3992317,
#     "tooltip": {
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderColor": "#333"
#     },
#     "animation": true,
#     "title": [
#         {
#             "text": "\u67f1\u72b6\u56fe\u793a\u4f8b",
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             }
#         }
#     ],
#     "legend": [
#         {
#             "show": true,
#             "orient": "horizontal",
#             "top": "top",
#             "data": [
#                 "\u84b8\u53d1\u91cf",
#                 "\u964d\u6c34\u91cf"
#             ],
#             "left": "center",
#             "selectedMode": "multiple",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",

# %%
#额外文本标签

bar = Bar("柱状图", extra_html_text_label=["bar_extra_html_text_label", "color:red"])
bar.add("商家A", attr, v1, is_stack=True)
bar.add("商家B", attr, v2, is_stack=True)
# bar.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <p style="color:red">bar_extra_html_text_label</p><div id="c7abfbc54839498e95a4d4362cfbbddb" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_c7abfbc54839498e95a4d4362cfbbddb = echarts.init(document.getElementById('c7abfbc54839498e95a4d4362cfbbddb'), 'light', {renderer: 'canvas'});
#
# var option_c7abfbc54839498e95a4d4362cfbbddb = {
#     "xAxis": [
#         {
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "nameLocation": "middle",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "data": [
#                 "1\u6708",
#                 "2\u6708",
#                 "3\u6708",
#                 "4\u6708",
#                 "5\u6708",
#                 "6\u6708",
#                 "7\u6708",
#                 "8\u6708",
#                 "9\u6708",
#                 "10\u6708",
#                 "11\u6708",
#                 "12\u6708"
#             ],
#             "nameGap": 25,
#             "boundaryGap": true
#         }
#     ],
#     "series": [
#         {
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 2.0,
#                 4.9,
#                 7.0,
#                 23.2,
#                 25.6,
#                 76.7,
#                 135.6,
#                 162.2,
#                 32.6,
#                 20.0,
#                 6.4,
#                 3.3
#             ],
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "seriesId": 8347312,
#             "stack": "stack_8347312",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             }
#         },
#         {
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 2.6,
#                 5.9,
#                 9.0,
#                 26.4,
#                 28.7,
#                 70.7,
#                 175.6,
#                 182.2,
#                 48.7,
#                 18.8,
#                 6.0,
#                 2.3
#             ],
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "seriesId": 8347312,
#             "stack": "stack_8347312",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "inverse": false,
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "nameLocation": "middle",
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "boundaryGap": true,
#             "nameGap": 25,
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             }
#         }
#     ],
#     "series_id": 8347312,
#     "tooltip": {
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderColor": "#333"
#     },
#     "animation": true,
#     "title": [
#         {
#             "text": "\u67f1\u72b6\u56fe",
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             }
#         }
#     ],
#     "legend": [
#         {
#             "show": true,
#             "orient": "horizontal",
#             "top": "top",
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "left": "center",
#             "selectedMode": "multiple",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "top": "center",
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     }
# };
# myChart_c7abfbc54839498e95a4d4362cfbbddb.setOption(option_c7abfbc54839498e95a4d4362cfbbddb);
#
#     });
# </script>

# %%
#控制 X/Y 轴坐标轴线颜色以及宽度

bar = Bar("柱状图")
bar.add(
    "商家A",
    attr,
    v1,
    xaxis_line_color="green",
    xaxis_line_width=5,
    xaxis_label_textcolor="black",
)
# bar.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="650bbd5591a4473da3e0ffd176e219eb" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_650bbd5591a4473da3e0ffd176e219eb = echarts.init(document.getElementById('650bbd5591a4473da3e0ffd176e219eb'), 'light', {renderer: 'canvas'});
#
# var option_650bbd5591a4473da3e0ffd176e219eb = {
#     "xAxis": [
#         {
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "color": "black",
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "nameLocation": "middle",
#             "axisLine": {
#                 "lineStyle": {
#                     "color": "green",
#                     "width": 5
#                 }
#             },
#             "data": [
#                 "1\u6708",
#                 "2\u6708",
#                 "3\u6708",
#                 "4\u6708",
#                 "5\u6708",
#                 "6\u6708",
#                 "7\u6708",
#                 "8\u6708",
#                 "9\u6708",
#                 "10\u6708",
#                 "11\u6708",
#                 "12\u6708"
#             ],
#             "nameGap": 25,
#             "boundaryGap": true
#         }
#     ],
#     "series": [
#         {
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 2.0,
#                 4.9,
#                 7.0,
#                 23.2,
#                 25.6,
#                 76.7,
#                 135.6,
#                 162.2,
#                 32.6,
#                 20.0,
#                 6.4,
#                 3.3
#             ],
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "seriesId": 4500573,
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "inverse": false,
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "nameLocation": "middle",
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "boundaryGap": true,
#             "nameGap": 25,
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             }
#         }
#     ],
#     "series_id": 4500573,
#     "tooltip": {
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderColor": "#333"
#     },
#     "animation": true,
#     "title": [
#         {
#             "text": "\u67f1\u72b6\u56fe",
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             }
#         }
#     ],
#     "legend": [
#         {
#             "show": true,
#             "orient": "horizontal",
#             "top": "top",
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "left": "center",
#             "selectedMode": "multiple",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "top": "center",
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     }
# };
# myChart_650bbd5591a4473da3e0ffd176e219eb.setOption(option_650bbd5591a4473da3e0ffd176e219eb);
#
#     });
# </script>

# %%
#进行两次或多次 add 的时候，有一次的某项数据缺失，可用 0 填充

bar = Bar("折线图示例")
bar.add("商家A", attr, v1)
bar.add("商家B", attr, [55, 60, 16, 20, 0, 0])
# bar.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="e24e4eb40e354c38b8b45e9b9471efc9" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_e24e4eb40e354c38b8b45e9b9471efc9 = echarts.init(document.getElementById('e24e4eb40e354c38b8b45e9b9471efc9'), 'light', {renderer: 'canvas'});
#
# var option_e24e4eb40e354c38b8b45e9b9471efc9 = {
#     "xAxis": [
#         {
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "nameLocation": "middle",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "nameGap": 25,
#             "boundaryGap": true
#         }
#     ],
#     "series": [
#         {
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "seriesId": 1790042,
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             }
#         },
#         {
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 55,
#                 60,
#                 16,
#                 20,
#                 0,
#                 0
#             ],
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "seriesId": 1790042,
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "inverse": false,
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "nameLocation": "middle",
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "boundaryGap": true,
#             "nameGap": 25,
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             }
#         }
#     ],
#     "series_id": 1790042,
#     "tooltip": {
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderColor": "#333"
#     },
#     "animation": true,
#     "title": [
#         {
#             "text": "\u6298\u7ebf\u56fe\u793a\u4f8b",
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             }
#         }
#     ],
#     "legend": [
#         {
#             "show": true,
#             "orient": "horizontal",
#             "top": "top",
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "left": "center",
#             "selectedMode": "multiple",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "top": "center",
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     }
# };
# myChart_e24e4eb40e354c38b8b45e9b9471efc9.setOption(option_e24e4eb40e354c38b8b45e9b9471efc9);
#
#     });
# </script>
