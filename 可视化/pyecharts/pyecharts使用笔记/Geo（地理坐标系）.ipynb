# %% [markdown]
# # 地理坐标系组件用于地图的绘制，支持在地理坐标系上绘制散点图，线集。

# %% [markdown]
# # Geo.add() 方法签名
#
# add(name, attr, value,
#     type="scatter",
#     maptype='china',
#     coordinate_region='中国',
#     symbol_size=12,
#     border_color="#111",
#     geo_normal_color="#323c48",
#     geo_emphasis_color="#2a333d",
#     geo_cities_coords=None,
#     is_roam=True, **kwargs)

# %% [markdown]
# name -> str
# 图例名称
# attr -> list
# 属性名称
# value -> list
# 属性所对应的值
# type -> str
# 图例类型，有'scatter', 'effectScatter', 'heatmap'可选。默认为 'scatter'
# maptype -> str
# 地图类型。 从 v0.3.2+ 起，地图已经变为扩展包，支持全国省份，全国城市，全国区县，全球国家等地图，具体请参考 地图自定义篇
# coordinate_region -> str
# 城市坐标所属国家。从 v0.5.7 引入，针对国际城市的地理位置的查找。默认为 中国。具体的国家/地区映射表参照 countries_regions_db.json。更多地理坐标信息可以参考 数据集篇
# symbol_size -> int
# 标记图形大小。默认为 12
# border_color -> str
# 地图边界颜色。默认为 '#111'
# geo_normal_color -> str
# 正常状态下地图区域的颜色。默认为 '#323c48'
# geo_emphasis_color -> str
# 高亮状态下地图区域的颜色。默认为 '#2a333d'
# geo_cities_coords -> dict
# 用户自定义地区经纬度，类似如 {'阿城': [126.58, 45.32],} 这样的字典。
# is_roam -> bool
# 是否开启鼠标缩放和平移漫游。默认为 True
# 如果只想要开启缩放或者平移，可以设置成'scale'或者'move'。设置成 True 为都开启

# %%
from pyecharts import Geo

# %%
#Scatter 类型（连续型）

data = [
    ("海门", 9),("鄂尔多斯", 12),("招远", 12),("舟山", 12),("齐齐哈尔", 14),("盐城", 15),
    ("赤峰", 16),("青岛", 18),("乳山", 18),("金昌", 19),("泉州", 21),("莱西", 21),
    ("日照", 21),("胶南", 22),("南通", 23),("拉萨", 24),("云浮", 24),("梅州", 25),
    ("文登", 25),("上海", 25),("攀枝花", 25),("威海", 25),("承德", 25),("厦门", 26),
    ("汕尾", 26),("潮州", 26),("丹东", 27),("太仓", 27),("曲靖", 27),("烟台", 28),
    ("福州", 29),("瓦房店", 30),("即墨", 30),("抚顺", 31),("玉溪", 31),("张家口", 31),
    ("阳泉", 31),("莱州", 32),("湖州", 32),("汕头", 32),("昆山", 33),("宁波", 33),
    ("湛江", 33),("揭阳", 34),("荣成", 34),("连云港", 35),("葫芦岛", 35),("常熟", 36),
    ("东莞", 36),("河源", 36),("淮安", 36),("泰州", 36),("南宁", 37),("营口", 37),
    ("惠州", 37),("江阴", 37),("蓬莱", 37),("韶关", 38),("嘉峪关", 38),("广州", 38),
    ("延安", 38),("太原", 39),("清远", 39),("中山", 39),("昆明", 39),("寿光", 40),
    ("盘锦", 40),("长治", 41),("深圳", 41),("珠海", 42),("宿迁", 43),("咸阳", 43),
    ("铜川", 44),("平度", 44),("佛山", 44),("海口", 44),("江门", 45),("章丘", 45),
    ("肇庆", 46),("大连", 47),("临汾", 47),("吴江", 47),("石嘴山", 49),("沈阳", 50),
    ("苏州", 50),("茂名", 50),("嘉兴", 51),("长春", 51),("胶州", 52),("银川", 52),
    ("张家港", 52),("三门峡", 53),("锦州", 54),("南昌", 54),("柳州", 54),("三亚", 54),
    ("自贡", 56),("吉林", 56),("阳江", 57),("泸州", 57),("西宁", 57),("宜宾", 58),
    ("呼和浩特", 58),("成都", 58),("大同", 58),("镇江", 59),("桂林", 59),("张家界", 59),
    ("宜兴", 59),("北海", 60),("西安", 61),("金坛", 62),("东营", 62),("牡丹江", 63),
    ("遵义", 63),("绍兴", 63),("扬州", 64),("常州", 64),("潍坊", 65),("重庆", 66),
    ("台州", 67),("南京", 67),("滨州", 70),("贵阳", 71),("无锡", 71),("本溪", 71),
    ("克拉玛依", 72),("渭南", 72),("马鞍山", 72),("宝鸡", 72),("焦作", 75),("句容", 75),
    ("北京", 79),("徐州", 79),("衡水", 80),("包头", 80),("绵阳", 80),("乌鲁木齐", 84),
    ("枣庄", 84),("杭州", 84),("淄博", 85),("鞍山", 86),("溧阳", 86),("库尔勒", 86),
    ("安阳", 90),("开封", 90),("济南", 92),("德阳", 93),("温州", 95),("九江", 96),
    ("邯郸", 98),("临安", 99),("兰州", 99),("沧州", 100),("临沂", 103),("南充", 104),
    ("天津", 105),("富阳", 106),("泰安", 112),("诸暨", 112),("郑州", 113),("哈尔滨", 114),
    ("聊城", 116),("芜湖", 117),("唐山", 119),("平顶山", 119),("邢台", 119),("德州", 120),
    ("济宁", 120),("荆州", 127),("宜昌", 130),("义乌", 132),("丽水", 133),("洛阳", 134),
    ("秦皇岛", 136),("株洲", 143),("石家庄", 147),("莱芜", 148),("常德", 152),("保定", 153),
    ("湘潭", 154),("金华", 157),("岳阳", 169),("长沙", 175),("衢州", 177),("廊坊", 193),
    ("菏泽", 194),("合肥", 229),("武汉", 273),("大庆", 279)]

geo = Geo(
    "全国主要城市空气质量",
    "data from pm2.5",
    title_color="#fff",
    title_pos="center",
    width=1200,
    height=600,
    background_color="#404a59",
)
attr, value = geo.cast(data)
geo.add(
    "",
    attr,
    value,
    visual_range=[0, 200],
    visual_text_color="#fff",
    symbol_size=15,
    is_visualmap=True,
)
# geo.render()

#请配合 通用配置项 中的 Visualmap 使用
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="d2411de2b34b4655bbffaa155393c72e" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_d2411de2b34b4655bbffaa155393c72e = echarts.init(document.getElementById('d2411de2b34b4655bbffaa155393c72e'), 'light', {renderer: 'canvas'});
#
# var option_d2411de2b34b4655bbffaa155393c72e = {
#     "visualMap": {
#         "left": "left",
#         "showLabel": true,
#         "calculable": true,
#         "text": [
#             "high",
#             "low"
#         ],
#         "min": 0,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "max": 200,
#         "orient": "vertical",
#         "type": "continuous",
#         "top": "bottom",
#         "textStyle": {
#             "color": "#fff"
#         },
#         "splitNumber": 5
#     },
#     "toolbox": {
#         "top": "center",
#         "show": true,
#         "left": "95%",
#         "orient": "vertical",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "borderColor": "#333",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "formatter": "{b}: {c}",
#         "borderWidth": 0
#     },
#     "animation": true,
#     "backgroundColor": "#404a59",
#     "series": [
#         {
#             "symbolSize": 15,
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "type": "scatter",
#             "symbol": "circle",
#             "coordinateSystem": "geo",
#             "data": [
#                 {
#                     "value": [
#                         121.15,
#                         31.89,
#                         9
#                     ],
#                     "name": "\u6d77\u95e8"
#                 },
#                 {
#                     "value": [
#                         109.781327,
#                         39.608266,
#                         12
#                     ],
#                     "name": "\u9102\u5c14\u591a\u65af"
#                 },
#                 {
#                     "value": [
#                         120.38,
#                         37.35,
#                         12
#                     ],
#                     "name": "\u62db\u8fdc"
#                 },
#                 {
#                     "value": [
#                         122.207216,
#                         29.985295,
#                         12
#                     ],
#                     "name": "\u821f\u5c71"
#                 },
#                 {
#                     "value": [
#                         123.97,
#                         47.33,
#                         14
#                     ],
#                     "name": "\u9f50\u9f50\u54c8\u5c14"
#                 },
#                 {
#                     "value": [
#                         120.13,
#                         33.38,
#                         15
#                     ],
#                     "name": "\u76d0\u57ce"
#                 },
#                 {
#                     "value": [
#                         118.87,
#                         42.28,
#                         16
#                     ],
#                     "name": "\u8d64\u5cf0"
#                 },
#                 {
#                     "value": [
#                         120.33,
#                         36.07,
#                         18
#                     ],
#                     "name": "\u9752\u5c9b"
#                 },
#                 {
#                     "value": [
#                         121.52,
#                         36.89,
#                         18
#                     ],
#                     "name": "\u4e73\u5c71"
#                 },
#                 {
#                     "value": [
#                         102.188043,
#                         38.520089,
#                         19
#                     ],
#                     "name": "\u91d1\u660c"
#                 },
#                 {
#                     "value": [
#                         118.58,
#                         24.93,
#                         21
#                     ],
#                     "name": "\u6cc9\u5dde"
#                 },
#                 {
#                     "value": [
#                         120.53,
#                         36.86,
#                         21
#                     ],
#                     "name": "\u83b1\u897f"
#                 },
#                 {
#                     "value": [
#                         119.46,
#                         35.42,
#                         21
#                     ],
#                     "name": "\u65e5\u7167"
#                 },
#                 {
#                     "value": [
#                         119.97,
#                         35.88,
#                         22
#                     ],
#                     "name": "\u80f6\u5357"
#                 },
#                 {
#                     "value": [
#                         121.05,
#                         32.08,
#                         23
#                     ],
#                     "name": "\u5357\u901a"
#                 },
#                 {
#                     "value": [
#                         91.11,
#                         29.97,
#                         24
#                     ],
#                     "name": "\u62c9\u8428"
#                 },
#                 {
#                     "value": [
#                         112.02,
#                         22.93,
#                         24
#                     ],
#                     "name": "\u4e91\u6d6e"
#                 },
#                 {
#                     "value": [
#                         116.1,
#                         24.55,
#                         25
#                     ],
#                     "name": "\u6885\u5dde"
#                 },
#                 {
#                     "value": [
#                         122.05,
#                         37.2,
#                         25
#                     ],
#                     "name": "\u6587\u767b"
#                 },
#                 {
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         25
#                     ],
#                     "name": "\u4e0a\u6d77"
#                 },
#                 {
#                     "value": [
#                         101.718637,
#                         26.582347,
#                         25
#                     ],
#                     "name": "\u6500\u679d\u82b1"
#                 },
#                 {
#                     "value": [
#                         122.1,
#                         37.5,
#                         25
#                     ],
#                     "name": "\u5a01\u6d77"
#                 },
#                 {
#                     "value": [
#                         117.93,
#                         40.97,
#                         25
#                     ],
#                     "name": "\u627f\u5fb7"
#                 },
#                 {
#                     "value": [
#                         118.1,
#                         24.46,
#                         26
#                     ],
#                     "name": "\u53a6

# %%
#Scatter 类型（分段型）

geo = Geo(
    "全国主要城市空气质量",
    "data from pm2.5",
    title_color="#fff",
    title_pos="center",
    width=1200,
    height=600,
    background_color="#404a59",
)
attr, value = geo.cast(data)
geo.add(
    "",
    attr,
    value,
    visual_range=[0, 200],
    visual_text_color="#fff",
    symbol_size=15,
    is_visualmap=True,
    is_piecewise=True,
    visual_split_number=6,
)
# geo.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="398b071967c74e8ebb940821557e390c" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_398b071967c74e8ebb940821557e390c = echarts.init(document.getElementById('398b071967c74e8ebb940821557e390c'), 'light', {renderer: 'canvas'});
#
# var option_398b071967c74e8ebb940821557e390c = {
#     "visualMap": {
#         "left": "left",
#         "showLabel": true,
#         "calculable": true,
#         "text": [
#             "high",
#             "low"
#         ],
#         "min": 0,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "max": 200,
#         "orient": "vertical",
#         "type": "piecewise",
#         "top": "bottom",
#         "textStyle": {
#             "color": "#fff"
#         },
#         "splitNumber": 6
#     },
#     "toolbox": {
#         "top": "center",
#         "show": true,
#         "left": "95%",
#         "orient": "vertical",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "borderColor": "#333",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "formatter": "{b}: {c}",
#         "borderWidth": 0
#     },
#     "animation": true,
#     "backgroundColor": "#404a59",
#     "series": [
#         {
#             "symbolSize": 15,
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "type": "scatter",
#             "symbol": "circle",
#             "coordinateSystem": "geo",
#             "data": [
#                 {
#                     "value": [
#                         121.15,
#                         31.89,
#                         9
#                     ],
#                     "name": "\u6d77\u95e8"
#                 },
#                 {
#                     "value": [
#                         109.781327,
#                         39.608266,
#                         12
#                     ],
#                     "name": "\u9102\u5c14\u591a\u65af"
#                 },
#                 {
#                     "value": [
#                         120.38,
#                         37.35,
#                         12
#                     ],
#                     "name": "\u62db\u8fdc"
#                 },
#                 {
#                     "value": [
#                         122.207216,
#                         29.985295,
#                         12
#                     ],
#                     "name": "\u821f\u5c71"
#                 },
#                 {
#                     "value": [
#                         123.97,
#                         47.33,
#                         14
#                     ],
#                     "name": "\u9f50\u9f50\u54c8\u5c14"
#                 },
#                 {
#                     "value": [
#                         120.13,
#                         33.38,
#                         15
#                     ],
#                     "name": "\u76d0\u57ce"
#                 },
#                 {
#                     "value": [
#                         118.87,
#                         42.28,
#                         16
#                     ],
#                     "name": "\u8d64\u5cf0"
#                 },
#                 {
#                     "value": [
#                         120.33,
#                         36.07,
#                         18
#                     ],
#                     "name": "\u9752\u5c9b"
#                 },
#                 {
#                     "value": [
#                         121.52,
#                         36.89,
#                         18
#                     ],
#                     "name": "\u4e73\u5c71"
#                 },
#                 {
#                     "value": [
#                         102.188043,
#                         38.520089,
#                         19
#                     ],
#                     "name": "\u91d1\u660c"
#                 },
#                 {
#                     "value": [
#                         118.58,
#                         24.93,
#                         21
#                     ],
#                     "name": "\u6cc9\u5dde"
#                 },
#                 {
#                     "value": [
#                         120.53,
#                         36.86,
#                         21
#                     ],
#                     "name": "\u83b1\u897f"
#                 },
#                 {
#                     "value": [
#                         119.46,
#                         35.42,
#                         21
#                     ],
#                     "name": "\u65e5\u7167"
#                 },
#                 {
#                     "value": [
#                         119.97,
#                         35.88,
#                         22
#                     ],
#                     "name": "\u80f6\u5357"
#                 },
#                 {
#                     "value": [
#                         121.05,
#                         32.08,
#                         23
#                     ],
#                     "name": "\u5357\u901a"
#                 },
#                 {
#                     "value": [
#                         91.11,
#                         29.97,
#                         24
#                     ],
#                     "name": "\u62c9\u8428"
#                 },
#                 {
#                     "value": [
#                         112.02,
#                         22.93,
#                         24
#                     ],
#                     "name": "\u4e91\u6d6e"
#                 },
#                 {
#                     "value": [
#                         116.1,
#                         24.55,
#                         25
#                     ],
#                     "name": "\u6885\u5dde"
#                 },
#                 {
#                     "value": [
#                         122.05,
#                         37.2,
#                         25
#                     ],
#                     "name": "\u6587\u767b"
#                 },
#                 {
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         25
#                     ],
#                     "name": "\u4e0a\u6d77"
#                 },
#                 {
#                     "value": [
#                         101.718637,
#                         26.582347,
#                         25
#                     ],
#                     "name": "\u6500\u679d\u82b1"
#                 },
#                 {
#                     "value": [
#                         122.1,
#                         37.5,
#                         25
#                     ],
#                     "name": "\u5a01\u6d77"
#                 },
#                 {
#                     "value": [
#                         117.93,
#                         40.97,
#                         25
#                     ],
#                     "name": "\u627f\u5fb7"
#                 },
#                 {
#                     "value": [
#                         118.1,
#                         24.46,
#                         26
#                     ],
#                     "name": "\u53a6\

# %%
# HeatMap 类型

geo = Geo(
    "全国主要城市空气质量",
    "data from pm2.5",
    title_color="#fff",
    title_pos="center",
    width=1200,
    height=600,
    background_color="#404a59",
)
attr, value = geo.cast(data)
geo.add(
    "",
    attr,
    value,
    type="heatmap",
    is_visualmap=True,
    visual_range=[0, 300],
    visual_text_color="#fff",
)
# geo.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="b1f3f47f2bb54c2d9aedefb37f9f1b99" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_b1f3f47f2bb54c2d9aedefb37f9f1b99 = echarts.init(document.getElementById('b1f3f47f2bb54c2d9aedefb37f9f1b99'), 'light', {renderer: 'canvas'});
#
# var option_b1f3f47f2bb54c2d9aedefb37f9f1b99 = {
#     "visualMap": {
#         "left": "left",
#         "showLabel": true,
#         "calculable": true,
#         "text": [
#             "high",
#             "low"
#         ],
#         "min": 0,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "max": 300,
#         "orient": "vertical",
#         "type": "continuous",
#         "top": "bottom",
#         "textStyle": {
#             "color": "#fff"
#         },
#         "splitNumber": 5
#     },
#     "toolbox": {
#         "top": "center",
#         "show": true,
#         "left": "95%",
#         "orient": "vertical",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "borderColor": "#333",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "formatter": "{b}: {c}",
#         "borderWidth": 0
#     },
#     "animation": true,
#     "backgroundColor": "#404a59",
#     "series": [
#         {
#             "coordinateSystem": "geo",
#             "type": "heatmap",
#             "data": [
#                 {
#                     "value": [
#                         121.15,
#                         31.89,
#                         9
#                     ],
#                     "name": "\u6d77\u95e8"
#                 },
#                 {
#                     "value": [
#                         109.781327,
#                         39.608266,
#                         12
#                     ],
#                     "name": "\u9102\u5c14\u591a\u65af"
#                 },
#                 {
#                     "value": [
#                         120.38,
#                         37.35,
#                         12
#                     ],
#                     "name": "\u62db\u8fdc"
#                 },
#                 {
#                     "value": [
#                         122.207216,
#                         29.985295,
#                         12
#                     ],
#                     "name": "\u821f\u5c71"
#                 },
#                 {
#                     "value": [
#                         123.97,
#                         47.33,
#                         14
#                     ],
#                     "name": "\u9f50\u9f50\u54c8\u5c14"
#                 },
#                 {
#                     "value": [
#                         120.13,
#                         33.38,
#                         15
#                     ],
#                     "name": "\u76d0\u57ce"
#                 },
#                 {
#                     "value": [
#                         118.87,
#                         42.28,
#                         16
#                     ],
#                     "name": "\u8d64\u5cf0"
#                 },
#                 {
#                     "value": [
#                         120.33,
#                         36.07,
#                         18
#                     ],
#                     "name": "\u9752\u5c9b"
#                 },
#                 {
#                     "value": [
#                         121.52,
#                         36.89,
#                         18
#                     ],
#                     "name": "\u4e73\u5c71"
#                 },
#                 {
#                     "value": [
#                         102.188043,
#                         38.520089,
#                         19
#                     ],
#                     "name": "\u91d1\u660c"
#                 },
#                 {
#                     "value": [
#                         118.58,
#                         24.93,
#                         21
#                     ],
#                     "name": "\u6cc9\u5dde"
#                 },
#                 {
#                     "value": [
#                         120.53,
#                         36.86,
#                         21
#                     ],
#                     "name": "\u83b1\u897f"
#                 },
#                 {
#                     "value": [
#                         119.46,
#                         35.42,
#                         21
#                     ],
#                     "name": "\u65e5\u7167"
#                 },
#                 {
#                     "value": [
#                         119.97,
#                         35.88,
#                         22
#                     ],
#                     "name": "\u80f6\u5357"
#                 },
#                 {
#                     "value": [
#                         121.05,
#                         32.08,
#                         23
#                     ],
#                     "name": "\u5357\u901a"
#                 },
#                 {
#                     "value": [
#                         91.11,
#                         29.97,
#                         24
#                     ],
#                     "name": "\u62c9\u8428"
#                 },
#                 {
#                     "value": [
#                         112.02,
#                         22.93,
#                         24
#                     ],
#                     "name": "\u4e91\u6d6e"
#                 },
#                 {
#                     "value": [
#                         116.1,
#                         24.55,
#                         25
#                     ],
#                     "name": "\u6885\u5dde"
#                 },
#                 {
#                     "value": [
#                         122.05,
#                         37.2,
#                         25
#                     ],
#                     "name": "\u6587\u767b"
#                 },
#                 {
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         25
#                     ],
#                     "name": "\u4e0a\u6d77"
#                 },
#                 {
#                     "value": [
#                         101.718637,
#                         26.582347,
#                         25
#                     ],
#                     "name": "\u6500\u679d\u82b1"
#                 },
#                 {
#                     "value": [
#                         122.1,
#                         37.5,
#                         25
#                     ],
#                     "name": "\u5a01\u6d77"
#                 },
#                 {
#                     "value": [
#                         117.93,
#                         40.97,
#                         25
#                     ],
#                     "name": "\u627f\u5fb7"
#                 },
#                 {
#                     "value": [
#                         118.1,
#                         24.46,
#                         26
#                     ],
#                     "name": "\u53a6\u95e8"
#                 },
#                 {
#                     "value": [
#                         115.375279,
#                         22.786211,
#                         26
#                     ],
#                     "name": "\u6c55\u5c3e"
#                 },
#                 {
#                     "value": [
#                         116.63,
#                         23.68,
#                         26
#                     ],
#                     "name": "\u6f6e\u5dde"
#                 },

# %%
# EffectScatter 类型（全国）

data = [
    ("海门", 9), ("鄂尔多斯", 12), ("招远", 12), ("舟山", 12), ("齐齐哈尔", 14), ("盐城", 15)
]
geo = Geo(
    "全国主要城市空气质量",
    "data from pm2.5",
    title_color="#fff",
    title_pos="center",
    width=1200,
    height=600,
    background_color="#404a59",
)
attr, value = geo.cast(data)
geo.add("", attr, value, type="effectScatter", is_random=True, effect_scale=5)
# geo.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="3a964df94fdf4108a4db00250911f9ee" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_3a964df94fdf4108a4db00250911f9ee = echarts.init(document.getElementById('3a964df94fdf4108a4db00250911f9ee'), 'light', {renderer: 'canvas'});
#
# var option_3a964df94fdf4108a4db00250911f9ee = {
#     "toolbox": {
#         "top": "center",
#         "show": true,
#         "left": "95%",
#         "orient": "vertical",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "borderColor": "#333",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "formatter": "{b}: {c}",
#         "borderWidth": 0
#     },
#     "animation": true,
#     "backgroundColor": "#404a59",
#     "series": [
#         {
#             "symbolSize": 12,
#             "symbol": "circle",
#             "type": "effectScatter",
#             "data": [
#                 {
#                     "value": [
#                         121.15,
#                         31.89,
#                         9
#                     ],
#                     "name": "\u6d77\u95e8"
#                 },
#                 {
#                     "value": [
#                         109.781327,
#                         39.608266,
#                         12
#                     ],
#                     "name": "\u9102\u5c14\u591a\u65af"
#                 },
#                 {
#                     "value": [
#                         120.38,
#                         37.35,
#                         12
#                     ],
#                     "name": "\u62db\u8fdc"
#                 },
#                 {
#                     "value": [
#                         122.207216,
#                         29.985295,
#                         12
#                     ],
#                     "name": "\u821f\u5c71"
#                 },
#                 {
#                     "value": [
#                         123.97,
#                         47.33,
#                         14
#                     ],
#                     "name": "\u9f50\u9f50\u54c8\u5c14"
#                 },
#                 {
#                     "value": [
#                         120.13,
#                         33.38,
#                         15
#                     ],
#                     "name": "\u76d0\u57ce"
#                 }
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "rippleEffect": {
#                 "brushType": "stroke",
#                 "period": 4,
#                 "scale": 5
#             },
#             "coordinateSystem": "geo",
#             "showEffectOn": "render"
#         }
#     ],
#     "color": [
#         "#726930",
#         "#444693",
#         "#546570",
#         "#d48265",
#         "#f47920",
#         "#918597",
#         "#905a3d",
#         "#61a0a8",
#         "#6e7074",
#         "#bda29a",
#         "#ef5b9c",
#         "#f6f5ec",
#         "#b2d235",
#         "#f05b72",
#         "#c4ccd3",
#         "#ac6767",
#         "#c23531",
#         "#6950a1",
#         "#2f4554",
#         "#2a5caa",
#         "#fab27b",
#         "#749f83",
#         "#6d8346",
#         "#1d953f",
#         "#ca8622"
#     ],
#     "geo": {
#         "roam": true,
#         "label": {
#             "emphasis": {
#                 "show": true,
#                 "textStyle": {
#                     "color": "#eee"
#                 }
#             }
#         },
#         "map": "china",
#         "itemStyle": {
#             "normal": {
#                 "borderColor": "#111",
#                 "areaColor": "#323c48"
#             },
#             "emphasis": {
#                 "areaColor": "#2a333d"
#             }
#         }
#     },
#     "title": [
#         {
#             "left": "center",
#             "subtext": "data from pm2.5",
#             "text": "\u5168\u56fd\u4e3b\u8981\u57ce\u5e02\u7a7a\u6c14\u8d28\u91cf",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#fff",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "legend": [
#         {
#             "show": true,
#             "left": "center",
#             "orient": "horizontal",
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple"
#         }
#     ],
#     "series_id": 7509585
# };
# myChart_3a964df94fdf4108a4db00250911f9ee.setOption(option_3a964df94fdf4108a4db00250911f9ee);
#
#     });
# </script>

# %%
#EffectScatter 类型（广东）

data = [("汕头市", 50), ("汕尾市", 60), ("揭阳市", 35), ("阳江市", 44), ("肇庆市", 72)]
geo = Geo(
    "广东城市空气质量",
    "data from pm2.5",
    title_color="#fff",
    title_pos="center",
    width=1200,
    height=600,
    background_color="#404a59",
)
attr, value = geo.cast(data)
geo.add(
    "",
    attr,
    value,
    maptype="广东",
    type="effectScatter",
    is_random=True,
    effect_scale=5,
    is_legend_show=False,
)
# geo.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'guangdong': '/nbextensions/echarts-china-provinces-js/guangdong'
#         }
#     });
# </script>
#     <div id="18c1ab0671ff4c2e8cb76301593ba406" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'guangdong'], function(echarts) {
#
# var myChart_18c1ab0671ff4c2e8cb76301593ba406 = echarts.init(document.getElementById('18c1ab0671ff4c2e8cb76301593ba406'), 'light', {renderer: 'canvas'});
#
# var option_18c1ab0671ff4c2e8cb76301593ba406 = {
#     "toolbox": {
#         "top": "center",
#         "show": true,
#         "left": "95%",
#         "orient": "vertical",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "borderColor": "#333",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "formatter": "{b}: {c}",
#         "borderWidth": 0
#     },
#     "animation": true,
#     "backgroundColor": "#404a59",
#     "series": [
#         {
#             "symbolSize": 12,
#             "symbol": "circle",
#             "type": "effectScatter",
#             "data": [
#                 {
#                     "value": [
#                         116.68,
#                         23.35,
#                         50
#                     ],
#                     "name": "\u6c55\u5934\u5e02"
#                 },
#                 {
#                     "value": [
#                         115.37,
#                         22.78,
#                         60
#                     ],
#                     "name": "\u6c55\u5c3e\u5e02"
#                 },
#                 {
#                     "value": [
#                         116.37,
#                         23.55,
#                         35
#                     ],
#                     "name": "\u63ed\u9633\u5e02"
#                 },
#                 {
#                     "value": [
#                         111.98,
#                         21.87,
#                         44
#                     ],
#                     "name": "\u9633\u6c5f\u5e02"
#                 },
#                 {
#                     "value": [
#                         112.47,
#                         23.05,
#                         72
#                     ],
#                     "name": "\u8087\u5e86\u5e02"
#                 }
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "rippleEffect": {
#                 "brushType": "stroke",
#                 "period": 4,
#                 "scale": 5
#             },
#             "coordinateSystem": "geo",
#             "showEffectOn": "render"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#ef5b9c",
#         "#905a3d",
#         "#f05b72",
#         "#ca8622",
#         "#b2d235",
#         "#749f83",
#         "#61a0a8",
#         "#546570",
#         "#444693",
#         "#6e7074",
#         "#2a5caa",
#         "#f6f5ec",
#         "#ac6767",
#         "#2f4554",
#         "#6950a1",
#         "#1d953f",
#         "#d48265",
#         "#726930",
#         "#918597",
#         "#6d8346",
#         "#c4ccd3",
#         "#fab27b",
#         "#f47920",
#         "#bda29a"
#     ],
#     "geo": {
#         "roam": true,
#         "label": {
#             "emphasis": {
#                 "show": true,
#                 "textStyle": {
#                     "color": "#eee"
#                 }
#             }
#         },
#         "map": "\u5e7f\u4e1c",
#         "itemStyle": {
#             "normal": {
#                 "borderColor": "#111",
#                 "areaColor": "#323c48"
#             },
#             "emphasis": {
#                 "areaColor": "#2a333d"
#             }
#         }
#     },
#     "title": [
#         {
#             "left": "center",
#             "subtext": "data from pm2.5",
#             "text": "\u5e7f\u4e1c\u57ce\u5e02\u7a7a\u6c14\u8d28\u91cf",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#fff",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "legend": [
#         {
#             "show": false,
#             "left": "center",
#             "orient": "horizontal",
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple"
#         }
#     ],
#     "series_id": 6543948
# };
# myChart_18c1ab0671ff4c2e8cb76301593ba406.setOption(option_18c1ab0671ff4c2e8cb76301593ba406);
#
#     });
# </script>

# %%
# 使用 coordinate_region 指定检索坐标的国家/地区

data = [("Oxford", 15), ("London", 12)]

geo = Geo(
    "英国主要城市空气质量",
    "data from pm2.5",
    title_color="#fff",
    title_pos="center",
    background_color="#404a59",
)
attr, value = geo.cast(data)
geo.add(
    "",
    attr,
    value,
    maptype="英国",
    # 使用 coordinate_region，指定检索英国范围内的坐标，如上述的 Oxford。
    # 默认为中国
    coordinate_region="英国",
    visual_range=[0, 200],
    visual_text_color="#fff",
    symbol_size=15,
    is_visualmap=True,
)

# geo.render()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-bd02c8fe6908> in <module>()
#      22     visual_text_color="#fff",
#      23     symbol_size=15,
# ---> 24     is_visualmap=True,
#      25 )
#      26
#
# d:\python\py35\lib\site-packages\pyecharts\charts\geo.py in add(self, *args, **kwargs)
#      64
#      65     def add(self, *args, **kwargs):
# ---> 66         self.__add(*args, **kwargs)
#      67         return self
#      68
#
# d:\python\py35\lib\site-packages\pyecharts\charts\geo.py in __add(self, name, attr, value, type, maptype, coordinate_region, symbol_size, border_color, geo_normal_color, geo_emphasis_color, geo_cities_coords, is_roam, **kwargs)
#     129         for _name, _value in zip(attr, value):
#     130             _coordinate = self.get_coordinate(
# --> 131                 _name, coordinate_region, raise_exception=True
#     132             )
#     133             _data_value = [_coordinate[0], _coordinate[1], _value]
#
# d:\python\py35\lib\site-packages\pyecharts\charts\geo.py in get_coordinate(self, name, region, raise_exception)
#      59         coordinate = get_coordinate(name, region=region)
#      60         if coordinate is None and raise_exception:
# ---> 61             raise ValueError("No coordinate is specified for {}".format(name))
#      62
#      63         return coordinate
#
# ValueError: No coordinate is specified for Oxford
