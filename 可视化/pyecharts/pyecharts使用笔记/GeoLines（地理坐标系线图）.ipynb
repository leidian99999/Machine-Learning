# %% [markdown]
# # 用于带有起点和终点信息的线数据的绘制，主要用于地图上的航线，路线的可视化。

# %% [markdown]
# ## GeoLines.add() 方法签名
#
# add(name, data,
#     maptype='china',
#     coordinate_region="中国",
#     symbol=None,
#     symbol_size=12,
#     border_color="#111",
#     geo_normal_color="#323c48",
#     geo_emphasis_color="#2a333d",
#     geo_cities_coords=None,
#     geo_effect_period=6,
#     geo_effect_traillength=0,
#     geo_effect_color='#fff',
#     geo_effect_symbol='circle',
#     geo_effect_symbolsize=5,
#     is_geo_effect_show=True,
#     is_roam=True, **kwargs)

# %% [markdown]
# name -> str
# 图例名称
# data -> [list], 包含列表的列表
# 数据项，数据中，每一行是一个『数据项』，每一列属于一个『维度』。每一行包含两个或三个数据，如 ["广州", "北京"] 或 ["广州", "北京"，100]，则指定从广州到北京。第三个值用于表示该 line 的数值，该值可省略。
# maptype -> str
# 地图类型。 从 v0.3.2+ 起，地图已经变为扩展包，支持全国省份，全国城市，全国区县，全球国家等地图，具体请参考 地图自定义篇
# coordinate_region -> str
# 城市坐标所属国家。从 v0.5.7 引入，针对国际城市的地理位置的查找。默认为 中国。具体的国家/地区映射表参照 countries_regions_db.json。更多地理坐标信息可以参考 数据集篇
# symbol -> str
# 线两端的标记类型，可以是一个数组分别指定两端，也可以是单个统一指定。
# symbol_size -> int
# 线两端的标记大小，可以是一个数组分别指定两端，也可以是单个统一指定。
# border_color -> str
# 地图边界颜色。默认为 '#111'
# geo_normal_color -> str
# 正常状态下地图区域的颜色。默认为 '#323c48'
# geo_emphasis_color -> str
# 高亮状态下地图区域的颜色。默认为 '#2a333d'
# geo_cities_coords -> dict
# 用户自定义地区经纬度，类似如 {'阿城': [126.58, 45.32],} 这样的字典。
# geo_effect_period -> int/float
# 特效动画的时间，单位为 s，默认为 6s
# geo_effect_traillength -> float
# 特效尾迹的长度。取从 0 到 1 的值，数值越大尾迹越长。默认为 0
# geo_effect_color -> str
# 特效标记的颜色。默认为 '#fff'
# geo_effect_symbol -> str
# 特效图形的标记。有 'circle', 'rect', 'roundRect', 'triangle', 'diamond', 'pin', 'arrow', 'plane' 可选。
# geo_effect_symbolsize -> int/list
# 特效标记的大小，可以设置成诸如 10 这样单一的数字，也可以用数组分开表示高和宽，例如 [20, 10] 表示标记宽为 20，高为 10。
# is_geo_effect_show -> bool
# 是否显示特效。
# is_roam -> bool
# 是否开启鼠标缩放和平移漫游。默认为 True
# 如果只想要开启缩放或者平移，可以设置成'scale'或者'move'。设置成 True 为都开启

# %%
from pyecharts import GeoLines, Style

# %%
style = Style(
    title_top="#fff",
    title_pos = "center",
    width=1200,
    height=600,
    background_color="#404a59"
)

data_guangzhou = [
    ["广州", "上海"],
    ["广州", "北京"],
    ["广州", "南京"],
    ["广州", "重庆"],
    ["广州", "兰州"],
    ["广州", "杭州"]
]
geolines = GeoLines("GeoLines 示例", **style.init_style)
geolines.add("从广州出发", data_guangzhou, is_legend_show=False)
# geolines.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="367bc3edd4fa40e684d37f2b4b9ef535" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_367bc3edd4fa40e684d37f2b4b9ef535 = echarts.init(document.getElementById('367bc3edd4fa40e684d37f2b4b9ef535'), 'light', {renderer: 'canvas'});
#
# var option_367bc3edd4fa40e684d37f2b4b9ef535 = {
#     "backgroundColor": "#404a59",
#     "legend": [
#         {
#             "top": "top",
#             "selectedMode": "multiple",
#             "left": "center",
#             "show": false,
#             "orient": "horizontal",
#             "data": [
#                 "\u4ece\u5e7f\u5dde\u51fa\u53d1"
#             ],
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "series_id": 798674,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "animation": true,
#     "tooltip": {
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         },
#         "trigger": "item",
#         "borderColor": "#333",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click"
#     },
#     "geo": {
#         "label": {
#             "emphasis": {
#                 "show": true,
#                 "textStyle": {
#                     "color": "#eee"
#                 }
#             }
#         },
#         "itemStyle": {
#             "emphasis": {
#                 "areaColor": "#2a333d"
#             },
#             "normal": {
#                 "borderColor": "#111",
#                 "areaColor": "#323c48"
#             }
#         },
#         "map": "china",
#         "roam": true
#     },
#     "series": [
#         {
#             "type": "lines",
#             "symbolSize": 12,
#             "name": "\u4ece\u5e7f\u5dde\u51fa\u53d1",
#             "lineStyle": {
#                 "normal": {
#                     "opacity": 1,
#                     "curveness": 0,
#                     "width": 1,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u4e0a\u6d77",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             121.473701,
#                             31.230416
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u5317\u4eac",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             116.407526,
#                             39.90403
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u5357\u4eac",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             118.78,
#                             32.04
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u91cd\u5e86",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             106.551556,
#                             29.563009
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u5170\u5dde",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             103.73,
#                             36.03
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u676d\u5dde",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             120.19,
#                             30.26
#                         ]
#                     ]
#                 }
#             ],
#             "zlevel": 2,
#             "symbol": [
#                 "none",
#                 "arrow"
#             ],
#             "effect": {
#                 "trailLength": 0,
#                 "symbol": "circle",
#                 "symbolSize": 5,
#                 "color": "#fff",
#                 "period": 6,
#                 "show": true
#             }
#         },
#         {
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "tooltip": {
#                 "formatter": "{b}"
#             },
#             "symbolSize": 10,
#             "coordinateSystem": "geo",
#             "name": "\u4ece\u5e7f\u5dde\u51fa\u53d1",
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5357\u4eac",
#                     "value": [
#                         118.78,
#                         32.04,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [

# %%
#添加配置

style_geo = style.add(
    is_label_show=True,
    line_curve=0.2,
    line_opacity=0.6,
    legend_text_color="#eee",
    legend_pos="right",
    geo_effect_symbol="plane",
    geo_effect_symbolsize=15,
    label_color=['#a6c84c', '#ffa022', '#46bee9'],
    label_pos="right",
    label_formatter="{b}",
    label_text_color="#eee",
)
geolines = GeoLines("GeoLines 示例", **style.init_style)
geolines.add("从广州出发", data_guangzhou, **style_geo)
# geolines.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="2a67807f9920482a94caf4aa096414c4" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_2a67807f9920482a94caf4aa096414c4 = echarts.init(document.getElementById('2a67807f9920482a94caf4aa096414c4'), 'light', {renderer: 'canvas'});
#
# var option_2a67807f9920482a94caf4aa096414c4 = {
#     "backgroundColor": "#404a59",
#     "legend": [
#         {
#             "top": "top",
#             "selectedMode": "multiple",
#             "left": "right",
#             "show": true,
#             "orient": "horizontal",
#             "data": [
#                 "\u4ece\u5e7f\u5dde\u51fa\u53d1"
#             ],
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#eee"
#             }
#         }
#     ],
#     "series_id": 7110096,
#     "color": [
#         "#a6c84c",
#         "#ffa022",
#         "#46bee9",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "animation": true,
#     "tooltip": {
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         },
#         "trigger": "item",
#         "borderColor": "#333",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click"
#     },
#     "geo": {
#         "label": {
#             "emphasis": {
#                 "show": true,
#                 "textStyle": {
#                     "color": "#eee"
#                 }
#             }
#         },
#         "itemStyle": {
#             "emphasis": {
#                 "areaColor": "#2a333d"
#             },
#             "normal": {
#                 "borderColor": "#111",
#                 "areaColor": "#323c48"
#             }
#         },
#         "map": "china",
#         "roam": true
#     },
#     "series": [
#         {
#             "type": "lines",
#             "symbolSize": 12,
#             "name": "\u4ece\u5e7f\u5dde\u51fa\u53d1",
#             "lineStyle": {
#                 "normal": {
#                     "opacity": 0.6,
#                     "curveness": 0.2,
#                     "width": 1,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u4e0a\u6d77",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             121.473701,
#                             31.230416
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u5317\u4eac",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             116.407526,
#                             39.90403
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u5357\u4eac",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             118.78,
#                             32.04
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u91cd\u5e86",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             106.551556,
#                             29.563009
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u5170\u5dde",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             103.73,
#                             36.03
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u676d\u5dde",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             120.19,
#                             30.26
#                         ]
#                     ]
#                 }
#             ],
#             "zlevel": 2,
#             "symbol": [
#                 "none",
#                 "arrow"
#             ],
#             "effect": {
#                 "trailLength": 0,
#                 "symbol": "path://M1705.06,1318.313v-89.254l-319.9-221.799l0.073-208.063c0.521-84.662-26.629-121.796-63.961-121.491c-37.332-0.305-64.482,36.829-63.961,121.491l0.073,208.063l-319.9,221.799v89.254l330.343-157.288l12.238,241.308l-134.449,92.931l0.531,42.034l175.125-42.917l175.125,42.917l0.531-42.034l-134.449-92.931l12.238-241.308L1705.06,1318.313z",
#                 "symbolSize": 15,
#                 "color": "#fff",
#                 "period": 6,
#                 "show": true
#             }
#         },
#         {
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": true,
#                     "position": "right",
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#eee"
#                     },
#                     "formatter": "{b}"
#                 }
#             },
#             "tooltip": {
#                 "formatter": "{b}"
#             },
#             "symbolSize": 10,
#             "coordinateSystem": "geo",
#             "name": "\u4ece\u5e7f\u5dde\u51fa\u53d1",
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5357

# %%
# 指定数值

data_guangzhou = [
    ["广州", "上海", 10],
    ["广州", "北京", 20],
    ["广州", "南京", 30],
    ["广州", "重庆", 40],
    ["广州", "兰州", 50],
    ["广州", "杭州", 60],
]
lines = GeoLines("GeoLines 示例", **style.init_style)
lines.add(
    "从广州出发", data_guangzhou, tooltip_formatter="{a} : {c}", **style_geo
)
# lines.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="95f11336a31f4b0ba5f71122746af4cb" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_95f11336a31f4b0ba5f71122746af4cb = echarts.init(document.getElementById('95f11336a31f4b0ba5f71122746af4cb'), 'light', {renderer: 'canvas'});
#
# var option_95f11336a31f4b0ba5f71122746af4cb = {
#     "backgroundColor": "#404a59",
#     "legend": [
#         {
#             "top": "top",
#             "selectedMode": "multiple",
#             "left": "right",
#             "show": true,
#             "orient": "horizontal",
#             "data": [
#                 "\u4ece\u5e7f\u5dde\u51fa\u53d1"
#             ],
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#eee"
#             }
#         }
#     ],
#     "series_id": 3897315,
#     "color": [
#         "#a6c84c",
#         "#ffa022",
#         "#46bee9",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "animation": true,
#     "tooltip": {
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         },
#         "trigger": "item",
#         "borderColor": "#333",
#         "triggerOn": "mousemove|click",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "formatter": "{a} : {c}"
#     },
#     "geo": {
#         "label": {
#             "emphasis": {
#                 "show": true,
#                 "textStyle": {
#                     "color": "#eee"
#                 }
#             }
#         },
#         "itemStyle": {
#             "emphasis": {
#                 "areaColor": "#2a333d"
#             },
#             "normal": {
#                 "borderColor": "#111",
#                 "areaColor": "#323c48"
#             }
#         },
#         "map": "china",
#         "roam": true
#     },
#     "series": [
#         {
#             "type": "lines",
#             "symbolSize": 12,
#             "name": "\u4ece\u5e7f\u5dde\u51fa\u53d1",
#             "lineStyle": {
#                 "normal": {
#                     "opacity": 0.6,
#                     "curveness": 0.2,
#                     "width": 1,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u4e0a\u6d77",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             121.473701,
#                             31.230416
#                         ]
#                     ],
#                     "value": 10
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u5317\u4eac",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             116.407526,
#                             39.90403
#                         ]
#                     ],
#                     "value": 20
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u5357\u4eac",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             118.78,
#                             32.04
#                         ]
#                     ],
#                     "value": 30
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u91cd\u5e86",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             106.551556,
#                             29.563009
#                         ]
#                     ],
#                     "value": 40
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u5170\u5dde",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             103.73,
#                             36.03
#                         ]
#                     ],
#                     "value": 50
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u676d\u5dde",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             120.19,
#                             30.26
#                         ]
#                     ],
#                     "value": 60
#                 }
#             ],
#             "zlevel": 2,
#             "symbol": [
#                 "none",
#                 "arrow"
#             ],
#             "effect": {
#                 "trailLength": 0,
#                 "symbol": "path://M1705.06,1318.313v-89.254l-319.9-221.799l0.073-208.063c0.521-84.662-26.629-121.796-63.961-121.491c-37.332-0.305-64.482,36.829-63.961,121.491l0.073,208.063l-319.9,221.799v89.254l330.343-157.288l12.238,241.308l-134.449,92.931l0.531,42.034l175.125-42.917l175.125,42.917l0.531-42.034l-134.449-92.931l12.238-241.308L1705.06,1318.313z",
#                 "symbolSize": 15,
#                 "color": "#fff",
#                 "period": 6,
#                 "show": true
#             }
#         },
#         {
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": true,
#                     "position": "right",
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#eee"
#                     },
#                     "formatter": "{b}"
#                 }
#             },
#             "tooltip": {
#                 "formatter": "{b}"
#             },
#             "symbolSize": 10,
#             "coordinateSystem": "geo",
#             "name": "\u4ece\u5e7f\u5dde\u51fa\u53d1",
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         0
#                     ]
#                 },
#                 {
#                     "name"

# %%
#多例模式

data_beijing = [
    ["北京", "上海"],
    ["北京", "广州"],
    ["北京", "南京"],
    ["北京", "重庆"],
    ["北京", "兰州"],
    ["北京", "杭州"]
]
geolines = GeoLines("GeoLines 示例", **style.init_style)
geolines.add("从广州出发", data_guangzhou, **style_geo)
geolines.add("从北京出发", data_beijing, **style_geo)
# geolines.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="56ebfa1829634633b13b8b25bac9f587" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_56ebfa1829634633b13b8b25bac9f587 = echarts.init(document.getElementById('56ebfa1829634633b13b8b25bac9f587'), 'light', {renderer: 'canvas'});
#
# var option_56ebfa1829634633b13b8b25bac9f587 = {
#     "backgroundColor": "#404a59",
#     "legend": [
#         {
#             "top": "top",
#             "selectedMode": "multiple",
#             "left": "right",
#             "show": true,
#             "orient": "horizontal",
#             "data": [
#                 "\u4ece\u5e7f\u5dde\u51fa\u53d1",
#                 "\u4ece\u5317\u4eac\u51fa\u53d1"
#             ],
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#eee"
#             }
#         }
#     ],
#     "series_id": 3535903,
#     "color": [
#         "#a6c84c",
#         "#ffa022",
#         "#46bee9",
#         "#a6c84c",
#         "#ffa022",
#         "#46bee9",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "animation": true,
#     "tooltip": {
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         },
#         "trigger": "item",
#         "borderColor": "#333",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click"
#     },
#     "geo": {
#         "label": {
#             "emphasis": {
#                 "show": true,
#                 "textStyle": {
#                     "color": "#eee"
#                 }
#             }
#         },
#         "itemStyle": {
#             "emphasis": {
#                 "areaColor": "#2a333d"
#             },
#             "normal": {
#                 "borderColor": "#111",
#                 "areaColor": "#323c48"
#             }
#         },
#         "map": "china",
#         "roam": true
#     },
#     "series": [
#         {
#             "type": "lines",
#             "symbolSize": 12,
#             "name": "\u4ece\u5e7f\u5dde\u51fa\u53d1",
#             "lineStyle": {
#                 "normal": {
#                     "opacity": 0.6,
#                     "curveness": 0.2,
#                     "width": 1,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u4e0a\u6d77",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             121.473701,
#                             31.230416
#                         ]
#                     ],
#                     "value": 10
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u5317\u4eac",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             116.407526,
#                             39.90403
#                         ]
#                     ],
#                     "value": 20
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u5357\u4eac",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             118.78,
#                             32.04
#                         ]
#                     ],
#                     "value": 30
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u91cd\u5e86",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             106.551556,
#                             29.563009
#                         ]
#                     ],
#                     "value": 40
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u5170\u5dde",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             103.73,
#                             36.03
#                         ]
#                     ],
#                     "value": 50
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u676d\u5dde",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             120.19,
#                             30.26
#                         ]
#                     ],
#                     "value": 60
#                 }
#             ],
#             "zlevel": 2,
#             "symbol": [
#                 "none",
#                 "arrow"
#             ],
#             "effect": {
#                 "trailLength": 0,
#                 "symbol": "path://M1705.06,1318.313v-89.254l-319.9-221.799l0.073-208.063c0.521-84.662-26.629-121.796-63.961-121.491c-37.332-0.305-64.482,36.829-63.961,121.491l0.073,208.063l-319.9,221.799v89.254l330.343-157.288l12.238,241.308l-134.449,92.931l0.531,42.034l175.125-42.917l175.125,42.917l0.531-42.034l-134.449-92.931l12.238-241.308L1705.06,1318.313z",
#                 "symbolSize": 15,
#                 "color": "#fff",
#                 "period": 6,
#                 "show": true
#             }
#         },
#         {
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": true,
#                     "position": "right",
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#eee"
#                     },
#                     "formatter": "{b}"
#                 }
#             },
#             "tooltip": {
#                 "formatter": "{b}"
#             },
#             "symbolSize": 10,
#             "coordinateSystem": "geo",
#             "name": "\u4ece\u5e7f\u5dde\u51fa\u53d1",
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         0
