# %% [markdown]
# # 箱形图是一种用作显示一组数据分散情况资料的统计图。它能显示出一组数据的最大值、最小值、中位数、下四分位数及上四分位数。
#
# # Boxplot.add() 方法签名

# %% [markdown]
# ## add(name, x_axis, y_axis, **kwargs)

# %% [markdown]
# name -> str
# 图例名称
# x_axis -> list
# x 坐标轴数据
# y_axis -> [list], 包含列表的列表
# y 坐标轴数据，二维数组的每一数组项（下例中的每行）是渲染一个 box，它含有五个量值，依次是：
# [min, Q1, median (or Q2), Q3, max]
# 可自行计算出所需五个数值，也可通过内置 prepare_data() 转换，prepare_data() 会将传入的嵌套列表中的数据转换为嵌套的 [min, Q1, median (or Q2), Q3, max]，如下所示：

# %%
from pyecharts import Boxplot

# %%
boxplot = Boxplot("箱形图")
x_axis = ['expr1', 'expr2', 'expr3', 'expr4', 'expr5']
y_axis = [
    [850, 740, 900, 1070, 930, 850, 950, 980, 980, 880,
    1000, 980, 930, 650, 760, 810, 1000, 1000, 960, 960],
    [960, 940, 960, 940, 880, 800, 850, 880, 900, 840,
    830, 790, 810, 880, 880, 830, 800, 790, 760, 800],
    [880, 880, 880, 860, 720, 720, 620, 860, 970, 950,
    880, 910, 850, 870, 840, 840, 850, 840, 840, 840],
    [890, 810, 810, 820, 800, 770, 760, 740, 750, 760,
    910, 920, 890, 860, 880, 720, 840, 850, 850, 780],
    [890, 840, 780, 810, 760, 810, 790, 810, 820, 850,
    870, 870, 810, 740, 810, 940, 950, 800, 810, 870]
]
_yaxis = boxplot.prepare_data(y_axis)       # 转换数据
boxplot.add("boxplot", x_axis, _yaxis)
# boxplot.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="45878b452f40444aacd2e355b3b6471b" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_45878b452f40444aacd2e355b3b6471b = echarts.init(document.getElementById('45878b452f40444aacd2e355b3b6471b'), 'light', {renderer: 'canvas'});
#
# var option_45878b452f40444aacd2e355b3b6471b = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "xAxis": [
#         {
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameLocation": "middle",
#             "show": true,
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "splitLine": {
#                 "show": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "data": [
#                 "expr1",
#                 "expr2",
#                 "expr3",
#                 "expr4",
#                 "expr5"
#             ],
#             "axisLabel": {
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "interval": "auto"
#             }
#         }
#     ],
#     "tooltip": {
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderColor": "#333",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "triggerOn": "mousemove|click",
#         "trigger": "item"
#     },
#     "legend": [
#         {
#             "selectedMode": "multiple",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "data": [
#                 "boxplot"
#             ],
#             "show": true,
#             "top": "top",
#             "left": "center"
#         }
#     ],
#     "series_id": 2598892,
#     "toolbox": {
#         "feature": {
#             "saveAsImage": {
#                 "title": "save as image",
#                 "show": true
#             },
#             "dataView": {
#                 "title": "data view",
#                 "show": true
#             },
#             "restore": {
#                 "title": "restore",
#                 "show": true
#             }
#         },
#         "left": "95%",
#         "show": true,
#         "top": "center",
#         "orient": "vertical"
#     },
#     "animation": true,
#     "title": [
#         {
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "text": "\u7bb1\u5f62\u56fe",
#             "left": "auto"
#         }
#     ],
#     "yAxis": [
#         {
#             "nameGap": 25,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "splitLine": {
#                 "show": true
#             },
#             "inverse": false,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "boundaryGap": true,
#             "type": "value",
#             "nameLocation": "middle",
#             "show": true,
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "rotate": 0,
#                 "margin": 8,
#                 "interval": "auto",
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "formatter": "{value} "
#             }
#         }
#     ],
#     "series": [
#         {
#             "seriesId": 2598892,
#             "markLine": {
#                 "data": []
#             },
#             "label": {
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 },
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": false,
#                     "position": "top"
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "type": "boxplot",
#             "data": [
#                 [
#                     650,
#                     850.0,
#                     940.0,
#                     980.0,
#                     1070
#                 ],
#                 [
#                     760,
#                     800.0,
#                     845.0,
#                     895.0,
#                     960
#                 ],
#                 [
#                     620,
#                     840.0,
#                     855.0,
#                     880.0,
#                     970
#                 ],
#                 [
#                     720,
#                     762.5,
#                     815.0,
#                     875.0,
#                     920
#                 ],
#                 [
#                     740,
#                     802.5,
#                     810.0,
#                     870.0,
#                     950
#                 ]
#             ],
#             "name": "boxplot"
#         }
#     ]
# };
# myChart_45878b452f40444aacd2e355b3b6471b.setOption(option_45878b452f40444aacd2e355b3b6471b);
#
#     });
# </script>

# %%
#或者直接在 add() 中转换

boxplot = Boxplot("箱形图")
x_axis = ['expr1', 'expr2']
y_axis1 = [
    [850, 740, 900, 1070, 930, 850, 950, 980, 980, 880,
    1000, 980, 930, 650, 760, 810, 1000, 1000, 960, 960],
    [960, 940, 960, 940, 880, 800, 850, 880, 900, 840,
    830, 790, 810, 880, 880, 830, 800, 790, 760, 800],
]
y_axis2 = [
    [890, 810, 810, 820, 800, 770, 760, 740, 750, 760,
    910, 920, 890, 860, 880, 720, 840, 850, 850, 780],
    [890, 840, 780, 810, 760, 810, 790, 810, 820, 850,
    870, 870, 810, 740, 810, 940, 950, 800, 810, 870]
]
boxplot.add("category1", x_axis, boxplot.prepare_data(y_axis1))
boxplot.add("category2", x_axis, boxplot.prepare_data(y_axis2))
# boxplot.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="8fd907527743460195398f9a08c5bdde" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_8fd907527743460195398f9a08c5bdde = echarts.init(document.getElementById('8fd907527743460195398f9a08c5bdde'), 'light', {renderer: 'canvas'});
#
# var option_8fd907527743460195398f9a08c5bdde = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "xAxis": [
#         {
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameLocation": "middle",
#             "show": true,
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "splitLine": {
#                 "show": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "data": [
#                 "expr1",
#                 "expr2"
#             ],
#             "axisLabel": {
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "interval": "auto"
#             }
#         }
#     ],
#     "tooltip": {
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderColor": "#333",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "triggerOn": "mousemove|click",
#         "trigger": "item"
#     },
#     "legend": [
#         {
#             "selectedMode": "multiple",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "data": [
#                 "category1",
#                 "category2"
#             ],
#             "show": true,
#             "top": "top",
#             "left": "center"
#         }
#     ],
#     "series_id": 714164,
#     "toolbox": {
#         "feature": {
#             "saveAsImage": {
#                 "title": "save as image",
#                 "show": true
#             },
#             "dataView": {
#                 "title": "data view",
#                 "show": true
#             },
#             "restore": {
#                 "title": "restore",
#                 "show": true
#             }
#         },
#         "left": "95%",
#         "show": true,
#         "top": "center",
#         "orient": "vertical"
#     },
#     "animation": true,
#     "title": [
#         {
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "text": "\u7bb1\u5f62\u56fe",
#             "left": "auto"
#         }
#     ],
#     "yAxis": [
#         {
#             "nameGap": 25,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "splitLine": {
#                 "show": true
#             },
#             "inverse": false,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "boundaryGap": true,
#             "type": "value",
#             "nameLocation": "middle",
#             "show": true,
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "rotate": 0,
#                 "margin": 8,
#                 "interval": "auto",
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "formatter": "{value} "
#             }
#         }
#     ],
#     "series": [
#         {
#             "seriesId": 714164,
#             "markLine": {
#                 "data": []
#             },
#             "label": {
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 },
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": false,
#                     "position": "top"
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "type": "boxplot",
#             "data": [
#                 [
#                     650,
#                     850.0,
#                     940.0,
#                     980.0,
#                     1070
#                 ],
#                 [
#                     760,
#                     800.0,
#                     845.0,
#                     895.0,
#                     960
#                 ]
#             ],
#             "name": "category1"
#         },
#         {
#             "seriesId": 714164,
#             "markLine": {
#                 "data": []
#             },
#             "label": {
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 },
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": false,
#                     "position": "top"
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "type": "boxplot",
#             "data": [
#                 [
#                     720,
#                     762.5,
#                     815.0,
#                     875.0,
#                     920
#                 ],
#                 [
#                     740,
#                     802.5,
#                     810.0,
#                     870.0,
#                     950
#                 ]
#             ],
#             "name": "category2"
#         }
#     ]
# };
# myChart_8fd907527743460195398f9a08c5bdde.setOption(option_8fd907527743460195398f9a08c5bdde);
#
#     });
# </script>
