# %% [markdown]
# # Gauge.add() 方法签名
#
# add(name, attr, value,
#     scale_range=None,
#     angle_range=None, **kwargs)

# %% [markdown]
# name -> str
# 图例名称
# attr -> list
# 属性名称
# value -> list
# 属性所对应的值
# scale_range -> list
# 仪表盘数据范围。默认为 [0, 100]
# angle_range -> list
# 仪表盘角度范围。默认为 [225, -45]

# %%
from pyecharts import Gauge

# %%
gauge = Gauge("仪表盘示例")
gauge.add("业务指标", "完成率", 66.66)
# gauge.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="5d9e0eb3fbec48e5b4ebc8514f5cf89c" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_5d9e0eb3fbec48e5b4ebc8514f5cf89c = echarts.init(document.getElementById('5d9e0eb3fbec48e5b4ebc8514f5cf89c'), 'light', {renderer: 'canvas'});
#
# var option_5d9e0eb3fbec48e5b4ebc8514f5cf89c = {
#     "series": [
#         {
#             "max": 100,
#             "data": [
#                 {
#                     "name": "\u5b8c\u6210\u7387",
#                     "value": 66.66
#                 }
#             ],
#             "detail": {
#                 "formatter": "{value}%"
#             },
#             "type": "gauge",
#             "startAngle": 225,
#             "endAngle": -45,
#             "min": 0,
#             "name": "\u4e1a\u52a1\u6307\u6807"
#         }
# ...

# %%
gauge = Gauge("仪表盘示例")
gauge.add(
    "业务指标",
    "完成率",
    166.66,
    angle_range=[180, 0],
    scale_range=[0, 200],
    is_legend_show=False,
)
# gauge.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="4d03b470f97f44b0ac5f168026431944" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_4d03b470f97f44b0ac5f168026431944 = echarts.init(document.getElementById('4d03b470f97f44b0ac5f168026431944'), 'light', {renderer: 'canvas'});
#
# var option_4d03b470f97f44b0ac5f168026431944 = {
#     "series": [
#         {
#             "max": 200,
#             "data": [
#                 {
#                     "name": "\u5b8c\u6210\u7387",
#                     "value": 166.66
#                 }
#             ],
#             "detail": {
#                 "formatter": "{value}%"
#             },
#             "type": "gauge",
#             "startAngle": 180,
#             "endAngle": 0,
#             "min": 0,
#             "name": "\u4e1a\u52a1\u6307\u6807"
#         }
# ...
