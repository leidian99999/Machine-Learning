# %% [markdown]
# # EffectScatter.add() 方法签名

# %% [markdown]
# add(name, x_axis, y_axis,
#     symbol_size=10, **kwargs)

# %% [markdown]
# name -> str
# 图例名称
# x_axis -> list
# x 坐标轴数据
# y_axis -> list
# y 坐标轴数据
# symbol_size -> int
# 标记图形大小，默认为 10

# %%
from pyecharts import EffectScatter

# %%
v1 = [10, 20, 30, 40, 50, 60]
v2 = [25, 20, 15, 10, 60, 33]
es = EffectScatter("动态散点图示例")
es.add("effectScatter", v1, v2)
# es.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="4a7a832b0d23446482003f7761b5d373" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_4a7a832b0d23446482003f7761b5d373 = echarts.init(document.getElementById('4a7a832b0d23446482003f7761b5d373'), 'light', {renderer: 'canvas'});
#
# var option_4a7a832b0d23446482003f7761b5d373 = {
#     "title": [
#         {
#             "left": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "top": "auto",
#             "text": "\u52a8\u6001\u6563\u70b9\u56fe\u793a\u4f8b"
#         }
#     ],
#     "toolbox": {
#         "feature": {
#             "saveAsImage": {
#                 "title": "save as image",
#                 "show": true
#             },
#             "restore": {
#                 "title": "restore",
#                 "show": true
#             },
#             "dataView": {
#                 "title": "data view",
#                 "show": true
#             }
#         },
#         "orient": "vertical",
#         "show": true,
#         "left": "95%",
#         "top": "center"
#     },
#     "animation": true,
#     "series_id": 4907224,
#     "legend": [
#         {
#             "selectedMode": "multiple",
#             "left": "center",
#             "data": [
#                 "effectScatter"
#             ],
#             "show": true,
#             "orient": "horizontal",
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "type": "value",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "margin": 8,
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "show": true,
#             "nameLocation": "middle",
#             "inverse": false,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameGap": 25,
#             "boundaryGap": true,
#             "splitLine": {
#                 "show": true
#             }
#         }
#     ],
#     "tooltip": {
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333",
#         "borderWidth": 0,
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "axisPointer": {
#             "type": "line"
#         }
#     },
#     "series": [
#         {
#             "type": "effectScatter",
#             "symbol": "circle",
#             "name": "effectScatter",
#             "symbolSize": 10,
#             "showEffectOn": "render",
#             "data": [
#                 [
#                     10,
#                     25
#                 ],
#                 [
#                     20,
#                     20
#                 ],
#                 [
#                     30,
#                     15
#                 ],
#                 [
#                     40,
#                     10
#                 ],
#                 [
#                     50,
#                     60
#                 ],
#                 [
#                     60,
#                     33
#                 ]
#             ],
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "seriesId": 4907224,
#             "rippleEffect": {
#                 "scale": 2.5,
#                 "brushType": "stroke",
#                 "period": 4
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "margin": 8,
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "show": true,
#             "nameLocation": "middle",
#             "inverse": false,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameGap": 25,
#             "boundaryGap": true,
#             "splitLine": {
#                 "show": true
#             }
#         }
#     ]
# };
# myChart_4a7a832b0d23446482003f7761b5d373.setOption(option_4a7a832b0d23446482003f7761b5d373);
#
#     });
# </script>

# %%
#动态散点图各种图形

es = EffectScatter("动态散点图各种图形示例")
es.add(
    "",
    [10],
    [10],
    symbol_size=20,
    effect_scale=3.5,
    effect_period=3,
    symbol="pin",
)
es.add(
    "",
    [20],
    [20],
    symbol_size=12,
    effect_scale=4.5,
    effect_period=4,
    symbol="rect",
)
es.add(
    "",
    [30],
    [30],
    symbol_size=30,
    effect_scale=5.5,
    effect_period=5,
    symbol="roundRect",
)
es.add(
    "",
    [40],
    [40],
    symbol_size=10,
    effect_scale=6.5,
    effect_brushtype="fill",
    symbol="diamond",
)
es.add(
    "",
    [50],
    [50],
    symbol_size=16,
    effect_scale=5.5,
    effect_period=3,
    symbol="arrow",
)
es.add(
    "",
    [60],
    [60],
    symbol_size=6,
    effect_scale=2.5,
    effect_period=3,
    symbol="triangle",
)
# es.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="ab730aaa6de7402990c0a53242b2251d" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_ab730aaa6de7402990c0a53242b2251d = echarts.init(document.getElementById('ab730aaa6de7402990c0a53242b2251d'), 'light', {renderer: 'canvas'});
#
# var option_ab730aaa6de7402990c0a53242b2251d = {
#     "title": [
#         {
#             "left": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "top": "auto",
#             "text": "\u52a8\u6001\u6563\u70b9\u56fe\u5404\u79cd\u56fe\u5f62\u793a\u4f8b"
#         }
#     ],
#     "toolbox": {
#         "feature": {
#             "saveAsImage": {
#                 "title": "save as image",
#                 "show": true
#             },
#             "restore": {
#                 "title": "restore",
#                 "show": true
#             },
#             "dataView": {
#                 "title": "data view",
#                 "show": true
#             }
#         },
#         "orient": "vertical",
#         "show": true,
#         "left": "95%",
#         "top": "center"
#     },
#     "animation": true,
#     "series_id": 4681247,
#     "legend": [
#         {
#             "selectedMode": "multiple",
#             "left": "center",
#             "data": [
#                 "",
#                 "",
#                 "",
#                 "",
#                 "",
#                 ""
#             ],
#             "show": true,
#             "orient": "horizontal",
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "type": "value",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "margin": 8,
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "show": true,
#             "nameLocation": "middle",
#             "inverse": false,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameGap": 25,
#             "boundaryGap": true,
#             "splitLine": {
#                 "show": true
#             }
#         }
#     ],
#     "tooltip": {
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333",
#         "borderWidth": 0,
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "axisPointer": {
#             "type": "line"
#         }
#     },
#     "series": [
#         {
#             "type": "effectScatter",
#             "symbol": "pin",
#             "symbolSize": 20,
#             "showEffectOn": "render",
#             "data": [
#                 [
#                     10,
#                     10
#                 ]
#             ],
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "seriesId": 4681247,
#             "rippleEffect": {
#                 "scale": 3.5,
#                 "brushType": "stroke",
#                 "period": 3
#             }
#         },
#         {
#             "type": "effectScatter",
#             "symbol": "rect",
#             "symbolSize": 12,
#             "showEffectOn": "render",
#             "data": [
#                 [
#                     20,
#                     20
#                 ]
#             ],
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "seriesId": 4681247,
#             "rippleEffect": {
#                 "scale": 4.5,
#                 "brushType": "stroke",
#                 "period": 4
#             }
#         },
#         {
#             "type": "effectScatter",
#             "symbol": "roundRect",
#             "symbolSize": 30,
#             "showEffectOn": "render",
#             "data": [
#                 [
#                     30,
#                     30
#                 ]
#             ],
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "seriesId": 4681247,
#             "rippleEffect": {
#                 "scale": 5.5,
#                 "brushType": "stroke",
#                 "period": 5
#             }
#         },
#         {
#             "type": "effectScatter",
#             "symbol": "diamond",
#             "symbolSize": 10,
#             "showEffectOn": "render",
#             "data": [
#                 [
#                     40,
#                     40
#                 ]
#             ],
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "seriesId": 4681247,
#             "rippleEffect": {
#                 "scale": 6.5,
#                 "brushType": "fill",
#                 "period": 4
#             }
#         },
#         {
#             "type": "effectScatter",
#             "symbol": "arrow",
#             "symbolSize": 16,
#             "showEffectOn": "render",
#             "data": [
#                 [
#                     50,
#                     50
#                 ]
#             ],
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "seriesId": 4681247,
#             "rippleEffect": {
#                 "scale": 5.5,
#                 "brushType": "stroke",
#                 "period": 3
#             }
#         },
#         {
#             "type": "effectScatter",
#             "symbol": "triangle",
#             "symbolSize": 6,
#             "showEffectOn": "render",
#             "data": [
#                 [
#                     60,
#                     60
#                 ]
#             ],
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "to

# %% [markdown]
# symbol -> str
# 标记图形，有'rect', 'roundRect', 'triangle', 'diamond', 'pin', 'arrow'可选
# effect_brushtype -> str
# 波纹绘制方式，有'stroke', 'fill'可选。默认为'stroke'
# effect_scale -> float
# 动画中波纹的最大缩放比例。默认为 2.5
# effect_period -> float
# 动画持续的时间。默认为 4（s）
