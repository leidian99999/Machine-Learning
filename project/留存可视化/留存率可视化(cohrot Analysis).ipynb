# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

pd.set_option('max_columns', 50)
mpl.rcParams['lines.linewidth'] = 2

# %matplotlib inline

# %%
df = pd.read_excel('relay-foods.xlsx')
df.head()
# Out:
#    OrderId  OrderDate  UserId  TotalCharges CommonId  PupId PickupDate
# 0      262 2009-01-11      47         50.67    TRQKD      2 2009-01-12
# 1      278 2009-01-20      47         26.60    4HH2S      3 2009-01-20
# 2      294 2009-02-03      47         38.71    3TRDC      2 2009-02-04
# 3      301 2009-02-06      47         53.38    NGAZJ      2 2009-02-09
# 4      302 2009-02-06      47         14.28    FFYHD      2 2009-02-09

# %% [markdown]
# ## 创建OrderPeriod列
#
# ### 由于是分析月度数据，所以不需要日

# %%
df['OrderPeriod'] = df.OrderDate.apply(lambda x: x.strftime('%Y-%m'))
df.head()
# Out:
#    OrderId  OrderDate  UserId  TotalCharges CommonId  PupId PickupDate  \
# 0      262 2009-01-11      47         50.67    TRQKD      2 2009-01-12
# 1      278 2009-01-20      47         26.60    4HH2S      3 2009-01-20
# 2      294 2009-02-03      47         38.71    3TRDC      2 2009-02-04
# 3      301 2009-02-06      47         53.38    NGAZJ      2 2009-02-09
# 4      302 2009-02-06      47         14.28    FFYHD      2 2009-02-09
#
#   OrderPeriod
# 0     2009-01
# 1     2009-01
# 2     2009-02
# 3     2009-02
# 4     2009-02

# %% [markdown]
# ## 创建一个新列，用户第一次购买的年月

# %%
df.set_index('UserId',inplace=True)
df.head()
# Out:
#         OrderId  OrderDate  TotalCharges CommonId  PupId PickupDate  \
# UserId
# 47          262 2009-01-11         50.67    TRQKD      2 2009-01-12
# 47          278 2009-01-20         26.60    4HH2S      3 2009-01-20
# 47          294 2009-02-03         38.71    3TRDC      2 2009-02-04
# 47          301 2009-02-06         53.38    NGAZJ      2 2009-02-09
# 47          302 2009-02-06         14.28    FFYHD      2 2009-02-09
#
#        OrderPeriod
# UserId
# 47         2009-01
# 47         2009-01
# 47         2009-02
# 47         2009-02
# 47         2009-02
