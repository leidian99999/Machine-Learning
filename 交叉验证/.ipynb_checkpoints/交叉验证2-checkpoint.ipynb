# %%
from sklearn.model_selection import GridSearchCV,KFold,train_test_split
from sklearn.metrics import make_scorer,accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_breast_cancer

# %%
data = load_breast_cancer()

# %%
X_train,X_test,y_train,y_test = train_test_split(data['data'],data['target'],train_size=0.8,random_state=0)
# Out:
# /home/leidian99/anaconda3/lib/python3.5/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
regressor = DecisionTreeClassifier(random_state=0)
parameters = {'max_depth':range(1,6)}
scoring_fnc = make_scorer(accuracy_score)
kfold = KFold(n_splits=10)

# %%
grid = GridSearchCV(regressor, parameters, scoring_fnc, cv=kfold)
grid = grid.fit(X_train, y_train)
reg = grid.best_estimator_

# %%
print('best score: %f'%grid.best_score_)
print('best parameters:')
for key in parameters.keys():
    print('%s: %d'%(key, reg.get_params()[key]))
# Out:
# best score: 0.938462
# best parameters:
# max_depth: 4

# %%
print('test score: %f'%reg.score(X_test, y_test))
# Out:
# test score: 0.956140

# %%
import pandas as pd
pd.DataFrame(grid.cv_results_).T
# Out:
# /home/leidian99/anaconda3/lib/python3.5/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/leidian99/anaconda3/lib/python3.5/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/leidian99/anaconda3/lib/python3.5/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/leidian99/anaconda3/lib/python3.5/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/leidian99/anaconda3/lib/python3.5/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split3_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/leidian99/anaconda3/lib/python3.5/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split4_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/leidian99/anaconda3/lib/python3.5/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split5_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/leidian99/anaconda3/lib/python3.5/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split6_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/leidian99/anaconda3/lib/python3.5/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split7_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/leidian99/anaconda3/lib/python3.5/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split8_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/leidian99/anaconda3/lib/python3.5/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split9_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/leidian99/anaconda3/lib/python3.5/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
#                                    0                 1                 2  \
# mean_fit_time             0.00258529        0.00332537        0.00447948
# mean_score_time          0.000644255       0.000407505       0.000370932
# mean_test_score             0.901099          0.934066          0.936264
# mean_train_score            0.923811          0.952871          0.969717
# param_max_depth                    1                 2                 3
# params              {'max_depth': 1}  {'max_depth': 2}  {'max_depth': 3}
# rank_test_score                    5                 3                 2
# split0_test_score           0.869565          0.934783          0.934783
# split0_train_score          0.929095           0.95599           0.97066
# split1_test_score           0.913043          0.934783          0.913043
# split1_train_score          0.924205          0.958435          0.968215
# split2_test_score           0.934783          0.956522          0.978261
# split2_train_score           0.92176            0.9511          0.968215
# split3_test_score           0.934783          0.934783          0.934783
# split3_train_score           0.92176          0.958435          0.963325
# split4_test_score           0.826087          0.869565          0.869565
# split4_train_score           0.92665           0.94621           0.97066
# split5_test_score           0.911111          0.955556          0.955556
# split5_train_score           0.92439           0.95122          0.973171
# split6_test_score           0.955556          0.955556          0.977778
# split6_train_score          0.917073          0.953659          0.965854
# split7_test_score           0.888889          0.888889          0.911111
# split7_train_score          0.921951          0.946341          0.978049
# split8_test_score           0.911111          0.977778          0.955556
# split8_train_score           0.92439           0.94878          0.970732
# split9_test_score           0.866667          0.933333          0.933333
# split9_train_score          0.926829          0.958537          0.968293
# std_fit_time             0.000645455       0.000189786       0.000115423
# std_score_time           0.000154656       5.91058e-05       9.60374e-06
# std_test_score             0.0368558         0.0308864         0.0314724
# std_train_score           0.00321232        0.00462563        0.00382722
#
#                                    3                 4
# mean_fit_time             0.00571883         0.0065989
# mean_score_time          0.000432324       0.000371718
# mean_test_score             0.938462          0.934066
# mean_train_score            0.984126          0.990721
# param_max_depth                    4                 5
# params              {'max_depth': 4}  {'max_depth': 5}
# rank_test_score                    1                 3
# split0_test_score           0.934783          0.913043
# split0_train_score           0.98044           0.99022
# split1_test_score           0.913043          0.913043
# split1_train_score          0.982885           0.99022
# split2_test_score                  1          0.978261
# split2_train_score          0.982885          0.987775
# split3_test_score           0.934783          0.934783
# split3_train_score          0.982885          0.992665
# split4_test_score           0.891304          0.869565
# split4_train_score          0.987775           0.99511
# split5_test_score           0.955556          0.955556
# split5_train_score          0.987805          0.990244
# split6_test_score           0.977778          0.977778
# split6_train_score          0.978049          0.987805
# split7_test_score           0.911111          0.911111
# split7_train_score          0.990244          0.995122
# split8_test_score           0.955556          0.977778
# split8_train_score          0.985366          0.990244
# split9_test_score           0.911111          0.911111
# split9_train_score          0.982927          0.987805
# std_fit_time             0.000467534       0.000716551
# std_score_time           9.83472e-05       7.54281e-06
# std_test_score             0.0321618         0.0351472
# std_train_score           0.00349845        0.00262782
